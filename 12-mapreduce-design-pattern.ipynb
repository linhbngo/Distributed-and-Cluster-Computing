# %% [markdown]
# # <center> MapReduce Design Patterns </center>
#
# ### <center>Based on "MapReduce Design Patterns" by Donald Miner and Adam Shook</center>
#
# ## <center> Linh B. Ngo </center>

# %% [markdown]
# ### Motivation
#
# - MapReduce is designed as a framework
#     - The solution has to fit into the framework
#     - There are clear boundaries on what can and cannot be done
#     - To create a solution that fits within existing boundaries is a challenge
# - MapReduce Design Pattern
#     - A template for solving common and general data manipulation problems with MapReduce
#     - Design patterns are not specific to a domain, but describe a general approach to solving a problem

# %% [markdown]
# ### Basic Patterns
#
# - Summarization
# - Filtering
# - Data Organization
# - Join
# - Metapatterns

# %% [markdown]
# ### Summarization
# - Grouping similar data together and perform an operation such as calculating a statistic, building an index, or just simply counting
# - Examples:
#     - Numerical summarizations
#     - Inverted Index
#     - Counting with Counters

# %%
# !hdfs dfs

# %% [markdown]
# ### Challenge
#
# Create a directory named **intro-to-hadoop** inside your user directory on HDFS

# %%
# !hdfs dfs -mkdir intro-to-hadoop

# %% [markdown]
# ### Challenge
#
# Upload the three data directories, **airlines**, **movielens**, and **text** into the newly created **intro-to-hadoop** directory.

# %%
# !hdfs dfs -put \
    /home/lngo/intro-to-hadoop/airlines/ \
    intro-to-hadoop/

# %%
# !hdfs dfs -put \
    /home/lngo/intro-to-hadoop/movielens/ \
    intro-to-hadoop/

# %%
# !hdfs dfs -put \
    /home/lngo/intro-to-hadoop/text/ \
    intro-to-hadoop/

# %% [markdown]
# ### Challenge
#
# Check the health status of the directories above in HDFS using fsck:
# ```
# hdfs fsck <path-to-directory> -files -blocks -locations
# ```

# %%
# !hdfs fsck intro-to-hadoop/text -files -blocks -locations

# %% [markdown]
# ## 1. The Hello World of Hadoop: Word Count

# %%
# !hdfs dfs -cat intro-to-hadoop/text/gutenberg-shakespeare.txt \
    2>/dev/null | head -n 100

# %%
# !hdfs dfs -cat intro-to-hadoop/text/gutenberg-shakespeare.txt \
    2>/dev/null \
    | head -n 100 \
    | python /home/lngo/intro-to-hadoop/wordcountMapper.py

# %%
# !hdfs dfs -cat intro-to-hadoop/text/gutenberg-shakespeare.txt \
    2>/dev/null \
    | head -n 100 \
    | python /home/lngo/intro-to-hadoop/wordcountMapper.py \
    | sort

# %%
# !hdfs dfs -cat intro-to-hadoop/text/gutenberg-shakespeare.txt \
    2>/dev/null \
    | head -n 100 \
    | python /home/lngo/intro-to-hadoop/wordcountMapper.py \
    | sort \
    | python /home/lngo/intro-to-hadoop/wordcountReducer.py

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/text/gutenberg-shakespeare.txt \
    -output intro-to-hadoop/output-wordcount \
    -file /home/lngo/intro-to-hadoop/wordcountMapper.py \
    -mapper wordcountMapper.py \
    -file /home/lngo/intro-to-hadoop/wordcountReducer.py \
    -reducer wordcountReducer.py \

# %%
# !hdfs dfs -ls intro-to-hadoop/output-wordcount

# %%
# !hdfs dfs -cat intro-to-hadoop/output-wordcount/part-00000 \
    2>/dev/null | head -n 100

# %% [markdown]
# ### Challenge
#
# Modify *wordcountMapper.py* so that punctuations and capitalization are no longer factors in determining unique words

# %% [markdown]
# ## 2. Movie Ratings and Recommendation
#
# An independent movie company is looking to invest in a new movie project. With limited finance, the company wants to
# analyze the reaction of audiences, particularly toward various movie genres, in order to identify beneficial
# movie project to focus on. The company relies on data collected from a publicly available recommendation service
# by [MovieLens](http://dl.acm.org/citation.cfm?id=2827872). This
# [dataset](http://files.grouplens.org/datasets/movielens/ml-10m-README.html) contains **22884377** ratings and **586994**
#  tag applications across **34208** movies. These data were created by **247753** users between January 09, 1995 and January 29, 2016. This dataset was generated on January 29, 2016.
#
# From this dataset, several analyses are possible, include the followings:
# 1.   Find movies which have the highest average ratings over the years and identify the corresponding genre.
# 2.   Find genres which have the highest average ratings over the years.
# 3.   Find users who rate movies most frequently in order to contact them for in-depth marketing analysis.
#
# These types of analyses, which are somewhat ambiguous, demand the ability to quickly process large amount of data in
# elatively short amount of time for decision support purposes. In these situations, the sizes of the data typically
# make analysis done on a single machine impossible and analysis done using a remote storage system impractical. For
# remainder of the lessons, we will learn how HDFS provides the basis to store massive amount of data and to enable
# the programming approach to analyze these data.

# %%
# !hdfs dfs -ls -h intro-to-hadoop/movielens

# %% [markdown]
# ### 2.1 Find movies which have the highest average ratings over the years and identify the corresponding genre
#
# - Find the average ratings of all movies over the years
# - Identify the corresponding genres for each movie

# %%
# !hdfs dfs -ls intro-to-hadoop/movielens

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/README.txt

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/links.csv \
    2>/dev/null | head -n 5

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/movies.csv \
    2>/dev/null | head -n 5

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv \
    2>/dev/null | head -n 5

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/tags.csv \
    2>/dev/null | head -n 5

# %% [markdown]
# ### Note:
#
# To write a MapReduce program, you have to be able to identify the necessary (Key,Value) that can contribute to the final realization of the required results. This is the reducing phase. From this (Key,Value) pair format, you will be able to develop the mapping phase.

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv \
    2>/dev/null | head -n 5 | python /home/lngo/intro-to-hadoop/avgRatingMapper01.py

# %% [markdown]
# #### *Do we really need the headers?*

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv \
    2>/dev/null | head -n 5 | python /home/lngo/intro-to-hadoop/avgRatingMapper02.py

# %% [markdown]
# #### *The outcome is correct. Is it useful?*

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv \
    2>/dev/null | head -n 5 | python /home/lngo/intro-to-hadoop/avgRatingMapper03.py

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv 2>/dev/null \
    | head -n 5 \
    | python /home/lngo/intro-to-hadoop/avgRatingMapper03.py \
    | sort \
    | python /home/lngo/intro-to-hadoop/avgRatingReducer01.py

# %% [markdown]
# #### Non-HDFS correctness test

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv 2>/dev/null \
    | head -n 1000 \
    | python /home/lngo/intro-to-hadoop/avgRatingMapper03.py \
    | grep Matrix
# Out:
# Matrix, The (1999)	3.5
# Matrix, The (1999)	4.0
# Matrix, The (1999)	2.5
# Matrix, The (1999)	4.5
# Matrix, The (1999)	2.0

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv 2>/dev/null \
    | head -n 1000 \
    | python /home/lngo/intro-to-hadoop/avgRatingMapper03.py \
    | grep Matrix \
    | sort \
    | python /home/lngo/intro-to-hadoop/avgRatingReducer01.py
# Out:
# Matrix, The (1999)	3.3

# %%
# Manual calculation check via python
(3.5+4.0+2.5+4.5+2.0)/5
# Out:
# 3.3

# %% [markdown]
# #### Full execution on HDFS

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-01 \
    -file /home/lngo/intro-to-hadoop/avgRatingMapper03.py \
    -mapper avgRatingMapper03.py \
    -file /home/lngo/intro-to-hadoop/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \

# %% [markdown]
# #### 2.1.1 First Error!!!
#
# Go back to the first few lines of the previously and look for the INFO line **Submitted application application_xxxx_xxxx**. Running the logs command of yarn with the provided application ID is a straightforward way to access all available log information for that application. The syntax to view yarn log is:
#
# ```
# !yarn logs -applicationId APPLICATION_ID
# ```

# %%
# Run the yarn view log command here
# !yarn logs -applicationId application_1476193845089_0123

# %% [markdown]
# However, this information is often massive, as it contains the aggregated logs from all tasks (map and reduce) of the job, which can be in the hundreds. The example below demonstrates this problem by displaying all the possible information of a single-task MapReduce job.
# In this example, the log of a container has three types of log (LogType):
# - stderr: Error messages from the actual task execution
# - stdout: Print out messages if the task includes them
# - syslog: Logging messages from the Hadoop MapReduce operation

# %% [markdown]
# One approach to reduce the number of possible output is to comment out all non-essential lines (lines containing **INFO**)

# %%
!'yarn logs -applicationId application_1476193845089_0123' | grep -v INFO
# Out:
# 17/01/18 09:43:22 INFO impl.TimelineClientImpl: Timeline service address: http://dscim003.palmetto.clemson.edu:8188/ws/v1/timeline/
# Unable to get ApplicationState. Attempting to fetch logs directly from the filesystem.
# 17/01/18 09:43:24 INFO zlib.ZlibFactory: Successfully loaded & initialized native-zlib library
# 17/01/18 09:43:24 INFO compress.CodecPool: Got brand-new decompressor [.deflate]
#
#
# Container: container_e176_1476193845089_0123_01_000004 on dsci001.palmetto.clemson.edu_45454
# ==============================================================================================
# LogType:directory.info
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:15155
# Log Contents:
# ls -l:
# total 32
# lrwxrwxrwx 1 lngo hadoop   75 Oct 21 08:33 avgRatingMapper03.py -> /data05/hadoop/yarn/local/usercache/lngo/filecache/138/avgRatingMapper03.py
# lrwxrwxrwx 1 lngo hadoop   76 Oct 21 08:33 avgRatingReducer01.py -> /data06/hadoop/yarn/local/usercache/lngo/filecache/139/avgRatingReducer01.py
# -rw------- 1 lngo hadoop  367 Oct 21 08:33 container_tokens
# lrwxrwxrwx 1 lngo hadoop  101 Oct 21 08:33 job.jar -> /data07/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/10/job.jar
# lrwxrwxrwx 1 lngo hadoop  101 Oct 21 08:33 job.xml -> /data08/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/11/job.xml
# -rwx------ 1 lngo hadoop 7810 Oct 21 08:33 launch_container.sh
# lrwxrwxrwx 1 lngo hadoop   55 Oct 21 08:33 mr-framework -> /data09/hadoop/yarn/local/filecache/12/mapreduce.tar.gz
# drwxr-s--- 2 lngo hadoop 4096 Oct 21 08:33 tmp
# find -L . -maxdepth 5 -ls:
# 20054341    4 drwxr-s---   3 lngo     hadoop       4096 Oct 21 08:33 .
# 17301874  124 -r-x------   1 lngo     bigdata    123610 Oct 21 08:33 ./job.xml
# 20054344    4 -rw-------   1 lngo     hadoop        367 Oct 21 08:33 ./container_tokens
# 23855717    4 drwx------   2 lngo     bigdata      4096 Oct 21 08:33 ./job.jar
# 23855713  108 -r-x------   1 lngo     bigdata    106909 Oct 21 08:33 ./job.jar/job.jar
# 51380246    4 drwxr-xr-x   3 yarn     hadoop       4096 Jul 20 17:38 ./mr-framework
# 51380250    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop
# 51387742    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/sbin
# 51387761    4 -r-xr-xr-x   1 yarn     hadoop       1455 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-dfs.cmd
# 51387755    8 -r-xr-xr-x   1 yarn     hadoop       4376 Apr 25 02:10 ./mr-framework/hadoop/sbin/yarn-daemon.sh
# 51387771    4 -r-xr-xr-x   1 yarn     hadoop       1438 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-secure-dns.sh
# 51387744    4 -r-xr-xr-x   1 yarn     hadoop       1428 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-yarn.sh
# 51387745    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-secure-dns.sh
# 51387765    4 -r-xr-xr-x   1 yarn     hadoop       1642 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-yarn.cmd
# 51387749    4 -r-xr-xr-x   1 yarn     hadoop       3128 Apr 25 02:10 ./mr-framework/hadoop/sbin/kms.sh
# 51387772    8 -r-xr-xr-x   1 yarn     hadoop       4161 Apr 25 02:10 ./mr-framework/hadoop/sbin/mr-jobhistory-daemon.sh
# 51387766    4 -r-xr-xr-x   1 yarn     hadoop       1260 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-balancer.sh
# 51387756    4 -r-xr-xr-x   1 yarn     hadoop       1770 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-all.cmd
# 51387751    4 -r-xr-xr-x   1 yarn     hadoop       1209 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-balancer.sh
# 51387748    4 -r-xr-xr-x   1 yarn     hadoop       2752 Apr 25 02:10 ./mr-framework/hadoop/sbin/distribute-exclude.sh
# 51387764    4 -r-xr-xr-x   1 yarn     hadoop       1543 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-all.sh
# 51387757    4 -r-xr-xr-x   1 yarn     hadoop       3815 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-dfs.sh
# 51387758    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr 25 02:10 ./mr-framework/hadoop/sbin/hdfs-config.cmd
# 51387754    4 -r-xr-xr-x   1 yarn     hadoop       3287 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-dfs.sh
# 51387767    4 -r-xr-xr-x   1 yarn     hadoop       1729 Apr 25 02:10 ./mr-framework/hadoop/sbin/refresh-namenodes.sh
# 51387759    4 -r-xr-xr-x   1 yarn     hadoop       2226 Apr 25 02:10 ./mr-framework/hadoop/sbin/slaves.sh
# 51387743    4 -r-xr-xr-x   1 yarn     hadoop       1434 Apr 25 02:10 ./mr-framework/hadoop/sbin/yarn-daemons.sh
# 51387760    4 -r-xr-xr-x   1 yarn     hadoop       2291 Apr 25 02:10 ./mr-framework/hadoop/sbin/httpfs.sh
# 51387752    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr 25 02:10 ./mr-framework/hadoop/sbin/hdfs-config.sh
# 51387770    4 -r-xr-xr-x   1 yarn     hadoop       1401 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-dfs.cmd
# 51387747    4 -r-xr-xr-x   1 yarn     hadoop       1779 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-all.cmd
# 51387750    4 -r-xr-xr-x   1 yarn     hadoop       1571 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-yarn.cmd
# 51387762    4 -r-xr-xr-x   1 yarn     hadoop       1552 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-all.sh
# 51387753    8 -r-xr-xr-x   1 yarn     hadoop       6546 Apr 25 02:10 ./mr-framework/hadoop/sbin/hadoop-daemon.sh
# 51387763    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-yarn.sh
# 51387746    4 -r-xr-xr-x   1 yarn     hadoop       1441 Apr 25 02:10 ./mr-framework/hadoop/sbin/hadoop-daemons.sh
# 51380346    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/lib
# 51380347    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/lib/native
# 51380354  760 -r-xr-xr-x   1 yarn     hadoop     775255 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadoop.so.1.0.0
# 51380356 1288 -r-xr-xr-x   1 yarn     hadoop    1318706 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadoop.a
# 51380355   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libsnappy.so.1
# 51380351 1456 -r-xr-xr-x   1 yarn     hadoop    1487436 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadooppipes.a
# 51380353  228 -r-xr-xr-x   1 yarn     hadoop     230209 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhdfs.so
# 51380355   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libsnappy.so
# 51380359  572 -r-xr-xr-x   1 yarn     hadoop     582696 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadooputils.a
# 51380354  760 -r-xr-xr-x   1 yarn     hadoop     775255 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadoop.so
# 51380355   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libsnappy.so.1.1.4
# 51380353  228 -r-xr-xr-x   1 yarn     hadoop     230209 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhdfs.so.0.0.0
# 51380348  360 -r-xr-xr-x   1 yarn     hadoop     366308 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhdfs.a
# 51387709    4 -r-xr-xr-x   1 yarn     hadoop       1366 Apr 25 02:10 ./mr-framework/hadoop/README.txt
# 51380252    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/libexec
# 51380282    4 -r-xr-xr-x   1 yarn     hadoop       2304 Apr 25 02:10 ./mr-framework/hadoop/libexec/mapred-config.sh
# 51380254    4 -r-xr-xr-x   1 yarn     hadoop       2131 Apr 25 02:10 ./mr-framework/hadoop/libexec/yarn-config.cmd
# 51380257    8 -r-xr-xr-x   1 yarn     hadoop       5749 Apr 25 02:10 ./mr-framework/hadoop/libexec/httpfs-config.sh
# 51380256   12 -r-xr-xr-x   1 yarn     hadoop       8270 Apr 25 02:10 ./mr-framework/hadoop/libexec/hadoop-config.cmd
# 51380277    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr 25 02:10 ./mr-framework/hadoop/libexec/hdfs-config.cmd
# 51380273    8 -r-xr-xr-x   1 yarn     hadoop       5431 Apr 25 02:10 ./mr-framework/hadoop/libexec/kms-config.sh
# 51380255    4 -r-xr-xr-x   1 yarn     hadoop       2215 Apr 25 02:10 ./mr-framework/hadoop/libexec/yarn-config.sh
# 51380270    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr 25 02:10 ./mr-framework/hadoop/libexec/hdfs-config.sh
# 51380253   12 -r-xr-xr-x   1 yarn     hadoop      11678 Apr 25 02:10 ./mr-framework/hadoop/libexec/hadoop-config.sh
# 51380278    4 -r-xr-xr-x   1 yarn     hadoop       1777 Apr 25 02:10 ./mr-framework/hadoop/libexec/mapred-config.cmd
# 51380284    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/bin
# 51380294    8 -r-xr-xr-x   1 yarn     hadoop       7120 Apr 25 02:10 ./mr-framework/hadoop/bin/hadoop
# 51380293    4 -r-xr-xr-x   1 yarn     hadoop        888 Apr 25 02:10 ./mr-framework/hadoop/bin/kill-secondary-name-node
# 51380285   16 -r-xr-xr-x   1 yarn     hadoop      14847 Apr 25 02:10 ./mr-framework/hadoop/bin/yarn
# 51380286   12 -r-xr-xr-x   1 yarn     hadoop       8786 Apr 25 02:10 ./mr-framework/hadoop/bin/hadoop.cmd
# 51380291  128 -r-xr-xr-x   1 yarn     hadoop     129158 Apr 25 02:10 ./mr-framework/hadoop/bin/test-container-executor
# 51380298   12 -r-xr-xr-x   1 yarn     hadoop       8782 Apr 25 02:10 ./mr-framework/hadoop/bin/hdfs.cmd
# 51380289    4 -r-xr-xr-x   1 yarn     hadoop        830 Apr 25 02:10 ./mr-framework/hadoop/bin/kill-name-node
# 51380297   16 -r-xr-xr-x   1 yarn     hadoop      12707 Apr 25 02:10 ./mr-framework/hadoop/bin/hdfs
# 51380292   12 -r-xr-xr-x   1 yarn     hadoop      12069 Apr 25 02:10 ./mr-framework/hadoop/bin/yarn.cmd
# 51380301    4 -r-xr-xr-x   1 yarn     hadoop       1857 Apr 25 02:10 ./mr-framework/hadoop/bin/rcc
# 51380295    8 -r-xr-xr-x   1 yarn     hadoop       6448 Apr 25 02:10 ./mr-framework/hadoop/bin/mapred
# 51380296  112 -r-xr-xr-x   1 yarn     hadoop     114438 Apr 25 02:10 ./mr-framework/hadoop/bin/container-executor
# 51380299    8 -r-xr-xr-x   1 yarn     hadoop       7465 Apr 25 02:10 ./mr-framework/hadoop/bin/mapred.cmd
# 51387710    4 -r-xr-xr-x   1 yarn     hadoop        101 Apr 25 02:10 ./mr-framework/hadoop/NOTICE.txt
# 51387711    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/etc
# 51387712    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop
# 51387735   12 -r-xr-xr-x   1 yarn     hadoop       9683 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-policy.xml
# 51387713    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 51387723    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 51387728    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 51387719    4 -r-xr-xr-x   1 yarn     hadoop        951 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-env.cmd
# 51387715    4 -r-xr-xr-x   1 yarn     hadoop       1631 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-log4j.properties
# 51387737    4 -r-xr-xr-x   1 yarn     hadoop         21 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-signature.secret
# 51387729    8 -r-xr-xr-x   1 yarn     hadoop       4529 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-env.sh
# 51387720    4 -r-xr-xr-x   1 yarn     hadoop        774 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/core-site.xml
# 51387718    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 51387717    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 51387722    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 51387714   16 -r-xr-xr-x   1 yarn     hadoop      12306 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 51387724    8 -r-xr-xr-x   1 yarn     hadoop       4567 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-env.sh
# 51387730    4 -r-xr-xr-x   1 yarn     hadoop        318 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/container-executor.cfg
# 51387732    4 -r-xr-xr-x   1 yarn     hadoop       1527 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-env.sh
# 51387740    4 -r-xr-xr-x   1 yarn     hadoop        620 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-site.xml
# 51387733    4 -r-xr-xr-x   1 yarn     hadoop       2490 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics.properties
# 51387738    4 -r-xr-xr-x   1 yarn     hadoop       1383 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-env.sh
# 51387734    4 -r-xr-xr-x   1 yarn     hadoop        775 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hdfs-site.xml
# 51387739    8 -r-xr-xr-x   1 yarn     hadoop       5511 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-site.xml
# 51387721    4 -r-xr-xr-x   1 yarn     hadoop       1449 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-env.sh
# 51387741    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 51387725    4 -r-xr-xr-x   1 yarn     hadoop        690 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-site.xml
# 51387731    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 51387716    4 -r-xr-xr-x   1 yarn     hadoop       2316 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/ssl-client.xml.example
# 51387727    4 -r-xr-xr-x   1 yarn     hadoop       2268 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/ssl-server.xml.example
# 51387726    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/slaves
# 51387736    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 51380344   16 -r-xr-xr-x   1 yarn     hadoop      15429 Apr 25 02:10 ./mr-framework/hadoop/LICENSE.txt
# 51380360    4 drwxr-xr-x   4 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share
# 51387699    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/doc
# 51387700    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/doc/hadoop
# 51380361    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop
# 51380363    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/yarn
# 51380494    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/kms
# 51387487    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/tools
# 51387376    4 drwxr-xr-x   7 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/hdfs
# 51382404    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/httpfs
# 51387259    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/common
# 51387635    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/mapreduce
# 51380304    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/include
# 51380305   36 -r-xr-xr-x   1 yarn     hadoop      33361 Apr 25 02:10 ./mr-framework/hadoop/include/hdfs.h
# 51380306    4 -r-xr-xr-x   1 yarn     hadoop       2441 Apr 25 02:10 ./mr-framework/hadoop/include/StringUtils.hh
# 51380341    4 -r-xr-xr-x   1 yarn     hadoop       3319 Apr 25 02:10 ./mr-framework/hadoop/include/TemplateFactory.hh
# 51380343    8 -r-xr-xr-x   1 yarn     hadoop       6330 Apr 25 02:10 ./mr-framework/hadoop/include/Pipes.hh
# 51380342    8 -r-xr-xr-x   1 yarn     hadoop       4514 Apr 25 02:10 ./mr-framework/hadoop/include/SerialUtils.hh
# 59638756    4 -r-x------   1 lngo     bigdata       793 Oct 21 08:33 ./avgRatingReducer01.py
# 20054339    4 -r-x------   1 lngo     bigdata       603 Oct 21 08:33 ./avgRatingMapper03.py
# 20054343    8 -rwx------   1 lngo     hadoop       7810 Oct 21 08:33 ./launch_container.sh
# 20054342    4 drwxr-s---   2 lngo     hadoop       4096 Oct 21 08:33 ./tmp
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:7810
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR="/usr/hdp/current/hadoop-client/conf"
# export STDOUT_LOGFILE_ENV="/data09/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/stdout"
# export JAVA_HOME="/usr/jdk64/jdk1.8.0_60"
# export NM_HOST="dsci001.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000001/*::/usr/share/java/mysql-connector-java.jar:/usr/hdp/2.4.2.0-258/tez/*:/usr/hdp/2.4.2.0-258/tez/lib/*:/usr/hdp/2.4.2.0-258/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.4.2.0-258/hadoop/lib/native:/usr/hdp/2.4.2.0-258/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data09/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004"
# export HADOOP_CLIENT_OPTS="-Xmx1024m -Xmx1024m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data02/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data03/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data04/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data05/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data06/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data07/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data08/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data09/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data10/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data11/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004,/data12/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004"
# export NM_AUX_SERVICE_mapreduce_shuffle="AAA0+gAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=
# "
# export NM_PORT="45454"
# export USER="lngo"
# export HADOOP_YARN_HOME="/usr/hdp/current/hadoop-yarn-nodemanager"
# export CLASSPATH="$PWD:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/*:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/lib/*:$PWD/mr-framework/hadoop/share/hadoop/common/*:$PWD/mr-framework/hadoop/share/hadoop/common/lib/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/lib/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/lib/*:/usr/hdp/2.4.2.0-258/hadoop/lib/hadoop-lzo-0.6.0.2.4.2.0-258.jar:/etc/hadoop/conf/secure:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*"
# export HADOOP_TOKEN_FILE_LOCATION="/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/container_tokens"
# export NM_AUX_SERVICE_spark_shuffle=""
# export HOME="/home/"
# export CONTAINER_ID="container_e176_1476193845089_0123_01_000004"
# export MALLOC_ARENA_MAX="4"
# ln -sf "/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/10/job.jar" "job.jar"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data05/hadoop/yarn/local/usercache/lngo/filecache/138/avgRatingMapper03.py" "avgRatingMapper03.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data06/hadoop/yarn/local/usercache/lngo/filecache/139/avgRatingReducer01.py" "avgRatingReducer01.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/11/job.xml" "job.xml"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data09/hadoop/yarn/local/filecache/12/mapreduce.tar.gz" "mr-framework"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# # Creating copy of launch script
# cp "launch_container.sh" "/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/launch_container.sh"
# chmod 640 "/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/launch_container.sh"
# # Determining directory contents
# echo "ls -l:" 1>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/directory.info"
# ls -l 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/directory.info"
# echo "find -L . -maxdepth 5 -ls:" 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/directory.info"
# find -L . -maxdepth 5 -ls 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/directory.info"
# echo "broken symlinks(find -L . -maxdepth 5 -type l -ls):" 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/directory.info"
# find -L . -maxdepth 5 -type l -ls 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/directory.info"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# End of LogType:launch_container.sh
#
# LogType:stderr
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:575
# Log Contents:
# Traceback (most recent call last):
#   File "/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000004/./avgRatingMapper03.py", line 9, in <module>
#     with open(movieFile, mode = 'r') as infile:
# IOError: [Errno 2] No such file or directory: './movielens/movies.csv'
# log4j:WARN No appenders could be found for logger (org.apache.hadoop.metrics2.impl.MetricsSystemImpl).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
# End of LogType:stderr
#
# LogType:stdout
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:0
# Log Contents:
# End of LogType:stdout
#
# LogType:syslog
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:12036
# Log Contents:
# 2016-10-21 08:33:26,047 WARN [main] org.apache.hadoop.metrics2.impl.MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-maptask.properties,hadoop-metrics2.properties
# minRecWrittenToEnableSkip_=9223372036854775807 HOST=null
# USER=lngo
# HADOOP_USER=null
# last tool output: |null|
#
# java.io.IOException: Stream closed
# 	at java.lang.ProcessBuilder$NullOutputStream.write(ProcessBuilder.java:433)
# 	at java.io.OutputStream.write(OutputStream.java:116)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:122)
# 	at java.io.BufferedOutputStream.flushBuffer(BufferedOutputStream.java:82)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:126)
# 	at java.io.DataOutputStream.write(DataOutputStream.java:107)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeUTF8(TextInputWriter.java:72)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeValue(TextInputWriter.java:51)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:106)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
# 2016-10-21 08:33:31,470 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:120)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
# 2016-10-21 08:33:31,471 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
# 2016-10-21 08:33:31,472 WARN [main] org.apache.hadoop.mapred.YarnChild: Exception running child : java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
#
# 2016-10-21 08:33:31,487 WARN [main] org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Could not delete hdfs://dsci/user/lngo/intro-to-hadoop/output-movielens-01/_temporary/1/_temporary/attempt_1476193845089_0123_m_000002_0
# End of LogType:syslog
#
#
#
# Container: container_e176_1476193845089_0123_01_000028 on dsci001.palmetto.clemson.edu_45454
# ==============================================================================================
# LogType:directory.info
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:15155
# Log Contents:
# ls -l:
# total 32
# lrwxrwxrwx 1 lngo hadoop   75 Oct 21 08:33 avgRatingMapper03.py -> /data05/hadoop/yarn/local/usercache/lngo/filecache/138/avgRatingMapper03.py
# lrwxrwxrwx 1 lngo hadoop   76 Oct 21 08:33 avgRatingReducer01.py -> /data06/hadoop/yarn/local/usercache/lngo/filecache/139/avgRatingReducer01.py
# -rw------- 1 lngo hadoop  367 Oct 21 08:33 container_tokens
# lrwxrwxrwx 1 lngo hadoop  101 Oct 21 08:33 job.jar -> /data07/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/10/job.jar
# lrwxrwxrwx 1 lngo hadoop  101 Oct 21 08:33 job.xml -> /data08/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/11/job.xml
# -rwx------ 1 lngo hadoop 7810 Oct 21 08:33 launch_container.sh
# lrwxrwxrwx 1 lngo hadoop   55 Oct 21 08:33 mr-framework -> /data09/hadoop/yarn/local/filecache/12/mapreduce.tar.gz
# drwxr-s--- 2 lngo hadoop 4096 Oct 21 08:33 tmp
# find -L . -maxdepth 5 -ls:
# 20054341    4 drwxr-s---   3 lngo     hadoop       4096 Oct 21 08:33 .
# 17301874  124 -r-x------   1 lngo     bigdata    123610 Oct 21 08:33 ./job.xml
# 20054344    4 -rw-------   1 lngo     hadoop        367 Oct 21 08:33 ./container_tokens
# 23855717    4 drwx------   2 lngo     bigdata      4096 Oct 21 08:33 ./job.jar
# 23855713  108 -r-x------   1 lngo     bigdata    106909 Oct 21 08:33 ./job.jar/job.jar
# 51380246    4 drwxr-xr-x   3 yarn     hadoop       4096 Jul 20 17:38 ./mr-framework
# 51380250    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop
# 51387742    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/sbin
# 51387761    4 -r-xr-xr-x   1 yarn     hadoop       1455 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-dfs.cmd
# 51387755    8 -r-xr-xr-x   1 yarn     hadoop       4376 Apr 25 02:10 ./mr-framework/hadoop/sbin/yarn-daemon.sh
# 51387771    4 -r-xr-xr-x   1 yarn     hadoop       1438 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-secure-dns.sh
# 51387744    4 -r-xr-xr-x   1 yarn     hadoop       1428 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-yarn.sh
# 51387745    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-secure-dns.sh
# 51387765    4 -r-xr-xr-x   1 yarn     hadoop       1642 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-yarn.cmd
# 51387749    4 -r-xr-xr-x   1 yarn     hadoop       3128 Apr 25 02:10 ./mr-framework/hadoop/sbin/kms.sh
# 51387772    8 -r-xr-xr-x   1 yarn     hadoop       4161 Apr 25 02:10 ./mr-framework/hadoop/sbin/mr-jobhistory-daemon.sh
# 51387766    4 -r-xr-xr-x   1 yarn     hadoop       1260 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-balancer.sh
# 51387756    4 -r-xr-xr-x   1 yarn     hadoop       1770 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-all.cmd
# 51387751    4 -r-xr-xr-x   1 yarn     hadoop       1209 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-balancer.sh
# 51387748    4 -r-xr-xr-x   1 yarn     hadoop       2752 Apr 25 02:10 ./mr-framework/hadoop/sbin/distribute-exclude.sh
# 51387764    4 -r-xr-xr-x   1 yarn     hadoop       1543 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-all.sh
# 51387757    4 -r-xr-xr-x   1 yarn     hadoop       3815 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-dfs.sh
# 51387758    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr 25 02:10 ./mr-framework/hadoop/sbin/hdfs-config.cmd
# 51387754    4 -r-xr-xr-x   1 yarn     hadoop       3287 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-dfs.sh
# 51387767    4 -r-xr-xr-x   1 yarn     hadoop       1729 Apr 25 02:10 ./mr-framework/hadoop/sbin/refresh-namenodes.sh
# 51387759    4 -r-xr-xr-x   1 yarn     hadoop       2226 Apr 25 02:10 ./mr-framework/hadoop/sbin/slaves.sh
# 51387743    4 -r-xr-xr-x   1 yarn     hadoop       1434 Apr 25 02:10 ./mr-framework/hadoop/sbin/yarn-daemons.sh
# 51387760    4 -r-xr-xr-x   1 yarn     hadoop       2291 Apr 25 02:10 ./mr-framework/hadoop/sbin/httpfs.sh
# 51387752    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr 25 02:10 ./mr-framework/hadoop/sbin/hdfs-config.sh
# 51387770    4 -r-xr-xr-x   1 yarn     hadoop       1401 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-dfs.cmd
# 51387747    4 -r-xr-xr-x   1 yarn     hadoop       1779 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-all.cmd
# 51387750    4 -r-xr-xr-x   1 yarn     hadoop       1571 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-yarn.cmd
# 51387762    4 -r-xr-xr-x   1 yarn     hadoop       1552 Apr 25 02:10 ./mr-framework/hadoop/sbin/start-all.sh
# 51387753    8 -r-xr-xr-x   1 yarn     hadoop       6546 Apr 25 02:10 ./mr-framework/hadoop/sbin/hadoop-daemon.sh
# 51387763    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr 25 02:10 ./mr-framework/hadoop/sbin/stop-yarn.sh
# 51387746    4 -r-xr-xr-x   1 yarn     hadoop       1441 Apr 25 02:10 ./mr-framework/hadoop/sbin/hadoop-daemons.sh
# 51380346    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/lib
# 51380347    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/lib/native
# 51380354  760 -r-xr-xr-x   1 yarn     hadoop     775255 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadoop.so.1.0.0
# 51380356 1288 -r-xr-xr-x   1 yarn     hadoop    1318706 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadoop.a
# 51380355   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libsnappy.so.1
# 51380351 1456 -r-xr-xr-x   1 yarn     hadoop    1487436 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadooppipes.a
# 51380353  228 -r-xr-xr-x   1 yarn     hadoop     230209 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhdfs.so
# 51380355   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libsnappy.so
# 51380359  572 -r-xr-xr-x   1 yarn     hadoop     582696 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadooputils.a
# 51380354  760 -r-xr-xr-x   1 yarn     hadoop     775255 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhadoop.so
# 51380355   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libsnappy.so.1.1.4
# 51380353  228 -r-xr-xr-x   1 yarn     hadoop     230209 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhdfs.so.0.0.0
# 51380348  360 -r-xr-xr-x   1 yarn     hadoop     366308 Apr 25 02:10 ./mr-framework/hadoop/lib/native/libhdfs.a
# 51387709    4 -r-xr-xr-x   1 yarn     hadoop       1366 Apr 25 02:10 ./mr-framework/hadoop/README.txt
# 51380252    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/libexec
# 51380282    4 -r-xr-xr-x   1 yarn     hadoop       2304 Apr 25 02:10 ./mr-framework/hadoop/libexec/mapred-config.sh
# 51380254    4 -r-xr-xr-x   1 yarn     hadoop       2131 Apr 25 02:10 ./mr-framework/hadoop/libexec/yarn-config.cmd
# 51380257    8 -r-xr-xr-x   1 yarn     hadoop       5749 Apr 25 02:10 ./mr-framework/hadoop/libexec/httpfs-config.sh
# 51380256   12 -r-xr-xr-x   1 yarn     hadoop       8270 Apr 25 02:10 ./mr-framework/hadoop/libexec/hadoop-config.cmd
# 51380277    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr 25 02:10 ./mr-framework/hadoop/libexec/hdfs-config.cmd
# 51380273    8 -r-xr-xr-x   1 yarn     hadoop       5431 Apr 25 02:10 ./mr-framework/hadoop/libexec/kms-config.sh
# 51380255    4 -r-xr-xr-x   1 yarn     hadoop       2215 Apr 25 02:10 ./mr-framework/hadoop/libexec/yarn-config.sh
# 51380270    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr 25 02:10 ./mr-framework/hadoop/libexec/hdfs-config.sh
# 51380253   12 -r-xr-xr-x   1 yarn     hadoop      11678 Apr 25 02:10 ./mr-framework/hadoop/libexec/hadoop-config.sh
# 51380278    4 -r-xr-xr-x   1 yarn     hadoop       1777 Apr 25 02:10 ./mr-framework/hadoop/libexec/mapred-config.cmd
# 51380284    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/bin
# 51380294    8 -r-xr-xr-x   1 yarn     hadoop       7120 Apr 25 02:10 ./mr-framework/hadoop/bin/hadoop
# 51380293    4 -r-xr-xr-x   1 yarn     hadoop        888 Apr 25 02:10 ./mr-framework/hadoop/bin/kill-secondary-name-node
# 51380285   16 -r-xr-xr-x   1 yarn     hadoop      14847 Apr 25 02:10 ./mr-framework/hadoop/bin/yarn
# 51380286   12 -r-xr-xr-x   1 yarn     hadoop       8786 Apr 25 02:10 ./mr-framework/hadoop/bin/hadoop.cmd
# 51380291  128 -r-xr-xr-x   1 yarn     hadoop     129158 Apr 25 02:10 ./mr-framework/hadoop/bin/test-container-executor
# 51380298   12 -r-xr-xr-x   1 yarn     hadoop       8782 Apr 25 02:10 ./mr-framework/hadoop/bin/hdfs.cmd
# 51380289    4 -r-xr-xr-x   1 yarn     hadoop        830 Apr 25 02:10 ./mr-framework/hadoop/bin/kill-name-node
# 51380297   16 -r-xr-xr-x   1 yarn     hadoop      12707 Apr 25 02:10 ./mr-framework/hadoop/bin/hdfs
# 51380292   12 -r-xr-xr-x   1 yarn     hadoop      12069 Apr 25 02:10 ./mr-framework/hadoop/bin/yarn.cmd
# 51380301    4 -r-xr-xr-x   1 yarn     hadoop       1857 Apr 25 02:10 ./mr-framework/hadoop/bin/rcc
# 51380295    8 -r-xr-xr-x   1 yarn     hadoop       6448 Apr 25 02:10 ./mr-framework/hadoop/bin/mapred
# 51380296  112 -r-xr-xr-x   1 yarn     hadoop     114438 Apr 25 02:10 ./mr-framework/hadoop/bin/container-executor
# 51380299    8 -r-xr-xr-x   1 yarn     hadoop       7465 Apr 25 02:10 ./mr-framework/hadoop/bin/mapred.cmd
# 51387710    4 -r-xr-xr-x   1 yarn     hadoop        101 Apr 25 02:10 ./mr-framework/hadoop/NOTICE.txt
# 51387711    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/etc
# 51387712    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop
# 51387735   12 -r-xr-xr-x   1 yarn     hadoop       9683 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-policy.xml
# 51387713    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 51387723    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 51387728    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 51387719    4 -r-xr-xr-x   1 yarn     hadoop        951 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-env.cmd
# 51387715    4 -r-xr-xr-x   1 yarn     hadoop       1631 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-log4j.properties
# 51387737    4 -r-xr-xr-x   1 yarn     hadoop         21 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-signature.secret
# 51387729    8 -r-xr-xr-x   1 yarn     hadoop       4529 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-env.sh
# 51387720    4 -r-xr-xr-x   1 yarn     hadoop        774 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/core-site.xml
# 51387718    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 51387717    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 51387722    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 51387714   16 -r-xr-xr-x   1 yarn     hadoop      12306 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 51387724    8 -r-xr-xr-x   1 yarn     hadoop       4567 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-env.sh
# 51387730    4 -r-xr-xr-x   1 yarn     hadoop        318 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/container-executor.cfg
# 51387732    4 -r-xr-xr-x   1 yarn     hadoop       1527 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-env.sh
# 51387740    4 -r-xr-xr-x   1 yarn     hadoop        620 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-site.xml
# 51387733    4 -r-xr-xr-x   1 yarn     hadoop       2490 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics.properties
# 51387738    4 -r-xr-xr-x   1 yarn     hadoop       1383 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-env.sh
# 51387734    4 -r-xr-xr-x   1 yarn     hadoop        775 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hdfs-site.xml
# 51387739    8 -r-xr-xr-x   1 yarn     hadoop       5511 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-site.xml
# 51387721    4 -r-xr-xr-x   1 yarn     hadoop       1449 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-env.sh
# 51387741    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 51387725    4 -r-xr-xr-x   1 yarn     hadoop        690 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-site.xml
# 51387731    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 51387716    4 -r-xr-xr-x   1 yarn     hadoop       2316 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/ssl-client.xml.example
# 51387727    4 -r-xr-xr-x   1 yarn     hadoop       2268 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/ssl-server.xml.example
# 51387726    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/slaves
# 51387736    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 51380344   16 -r-xr-xr-x   1 yarn     hadoop      15429 Apr 25 02:10 ./mr-framework/hadoop/LICENSE.txt
# 51380360    4 drwxr-xr-x   4 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share
# 51387699    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/doc
# 51387700    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/doc/hadoop
# 51380361    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop
# 51380363    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/yarn
# 51380494    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/kms
# 51387487    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/tools
# 51387376    4 drwxr-xr-x   7 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/hdfs
# 51382404    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/httpfs
# 51387259    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/common
# 51387635    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/share/hadoop/mapreduce
# 51380304    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr 25 02:10 ./mr-framework/hadoop/include
# 51380305   36 -r-xr-xr-x   1 yarn     hadoop      33361 Apr 25 02:10 ./mr-framework/hadoop/include/hdfs.h
# 51380306    4 -r-xr-xr-x   1 yarn     hadoop       2441 Apr 25 02:10 ./mr-framework/hadoop/include/StringUtils.hh
# 51380341    4 -r-xr-xr-x   1 yarn     hadoop       3319 Apr 25 02:10 ./mr-framework/hadoop/include/TemplateFactory.hh
# 51380343    8 -r-xr-xr-x   1 yarn     hadoop       6330 Apr 25 02:10 ./mr-framework/hadoop/include/Pipes.hh
# 51380342    8 -r-xr-xr-x   1 yarn     hadoop       4514 Apr 25 02:10 ./mr-framework/hadoop/include/SerialUtils.hh
# 59638756    4 -r-x------   1 lngo     bigdata       793 Oct 21 08:33 ./avgRatingReducer01.py
# 20054339    4 -r-x--x--x   1 lngo     bigdata       603 Oct 21 08:33 ./avgRatingMapper03.py
# 20054343    8 -rwx------   1 lngo     hadoop       7810 Oct 21 08:33 ./launch_container.sh
# 20054342    4 drwxr-s---   2 lngo     hadoop       4096 Oct 21 08:33 ./tmp
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:7810
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR="/usr/hdp/current/hadoop-client/conf"
# export STDOUT_LOGFILE_ENV="/data04/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028/stdout"
# export JAVA_HOME="/usr/jdk64/jdk1.8.0_60"
# export NM_HOST="dsci001.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000001/*::/usr/share/java/mysql-connector-java.jar:/usr/hdp/2.4.2.0-258/tez/*:/usr/hdp/2.4.2.0-258/tez/lib/*:/usr/hdp/2.4.2.0-258/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.4.2.0-258/hadoop/lib/native:/usr/hdp/2.4.2.0-258/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data04/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028"
# export HADOOP_CLIENT_OPTS="-Xmx1024m -Xmx1024m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data02/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data03/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data04/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data05/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data06/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data07/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data08/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data09/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data10/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data11/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028,/data12/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000028"
# ...
# 79692808    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 79692812   12 -r-xr-xr-x   1 yarn     hadoop       9683 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-policy.xml
# 79692797    4 -r-xr-xr-x   1 yarn     hadoop        774 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/core-site.xml
# 79692798    4 -r-xr-xr-x   1 yarn     hadoop       1449 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-env.sh
# 79692810    4 -r-xr-xr-x   1 yarn     hadoop       2490 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics.properties
# 79692805    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 79692795    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 79692796    4 -r-xr-xr-x   1 yarn     hadoop        951 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-env.cmd
# 79692809    4 -r-xr-xr-x   1 yarn     hadoop       1527 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-env.sh
# 79692817    4 -r-xr-xr-x   1 yarn     hadoop        620 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-site.xml
# 79692818    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 79692791   16 -r-xr-xr-x   1 yarn     hadoop      12306 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 79692803    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/slaves
# 79692813    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 79692790    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 79692816    8 -r-xr-xr-x   1 yarn     hadoop       5511 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/kms-site.xml
# 79692793    4 -r-xr-xr-x   1 yarn     hadoop       2316 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/ssl-client.xml.example
# 79692800    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 79692814    4 -r-xr-xr-x   1 yarn     hadoop         21 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-signature.secret
# 79692799    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 79692794    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr 25 02:10 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 79692787    4 -r-xr-xr-x   1 yarn     hadoop        101 Apr 25 02:10 ./mr-framework/hadoop/NOTICE.txt
# 98501002    4 -r-x------   1 lngo     bigdata       793 Oct 21 08:33 ./avgRatingReducer01.py
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:7810
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR="/usr/hdp/current/hadoop-client/conf"
# export STDOUT_LOGFILE_ENV="/data02/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/stdout"
# export JAVA_HOME="/usr/jdk64/jdk1.8.0_60"
# export NM_HOST="dsci040.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000001/*::/usr/share/java/mysql-connector-java.jar:/usr/hdp/2.4.2.0-258/tez/*:/usr/hdp/2.4.2.0-258/tez/lib/*:/usr/hdp/2.4.2.0-258/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.4.2.0-258/hadoop/lib/native:/usr/hdp/2.4.2.0-258/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data02/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010"
# export HADOOP_CLIENT_OPTS="-Xmx1024m -Xmx1024m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data02/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data03/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data04/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data05/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data06/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data07/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data08/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data09/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data10/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data11/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010,/data12/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010"
# export NM_AUX_SERVICE_mapreduce_shuffle="AAA0+gAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=
# "
# export NM_PORT="45454"
# export USER="lngo"
# export HADOOP_YARN_HOME="/usr/hdp/current/hadoop-yarn-nodemanager"
# export CLASSPATH="$PWD:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/*:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/lib/*:$PWD/mr-framework/hadoop/share/hadoop/common/*:$PWD/mr-framework/hadoop/share/hadoop/common/lib/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/lib/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/lib/*:/usr/hdp/2.4.2.0-258/hadoop/lib/hadoop-lzo-0.6.0.2.4.2.0-258.jar:/etc/hadoop/conf/secure:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*"
# export HADOOP_TOKEN_FILE_LOCATION="/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/container_tokens"
# export NM_AUX_SERVICE_spark_shuffle=""
# export HOME="/home/"
# export CONTAINER_ID="container_e176_1476193845089_0123_01_000010"
# export MALLOC_ARENA_MAX="4"
# ln -sf "/data01/hadoop/yarn/local/usercache/lngo/filecache/139/avgRatingReducer01.py" "avgRatingReducer01.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/10/job.jar" "job.jar"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data07/hadoop/yarn/local/filecache/10/mapreduce.tar.gz" "mr-framework"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data12/hadoop/yarn/local/usercache/lngo/filecache/138/avgRatingMapper03.py" "avgRatingMapper03.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/filecache/11/job.xml" "job.xml"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# # Creating copy of launch script
# cp "launch_container.sh" "/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/launch_container.sh"
# chmod 640 "/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/launch_container.sh"
# # Determining directory contents
# echo "ls -l:" 1>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/directory.info"
# ls -l 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/directory.info"
# echo "find -L . -maxdepth 5 -ls:" 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/directory.info"
# find -L . -maxdepth 5 -ls 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/directory.info"
# echo "broken symlinks(find -L . -maxdepth 5 -type l -ls):" 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/directory.info"
# find -L . -maxdepth 5 -type l -ls 1>>"/data01/hadoop/yarn/log/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/directory.info"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# End of LogType:launch_container.sh
#
# LogType:stderr
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:815
# Log Contents:
# sh: module: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `BASH_FUNC_module'
# sh: module: line 1: syntax error: unexpected end of file
# sh: error importing function definition for `BASH_FUNC_module'
# Traceback (most recent call last):
#   File "/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1476193845089_0123/container_e176_1476193845089_0123_01_000010/./avgRatingMapper03.py", line 9, in <module>
#     with open(movieFile, mode = 'r') as infile:
# IOError: [Errno 2] No such file or directory: './movielens/movies.csv'
# log4j:WARN No appenders could be found for logger (org.apache.hadoop.metrics2.impl.MetricsSystemImpl).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
# End of LogType:stderr
#
# LogType:stdout
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:0
# Log Contents:
# End of LogType:stdout
#
# LogType:syslog
# Log Upload Time:Fri Oct 21 08:33:56 -0400 2016
# LogLength:12020
# Log Contents:
# 2016-10-21 08:33:33,670 WARN [main] org.apache.hadoop.metrics2.impl.MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-maptask.properties,hadoop-metrics2.properties
# minRecWrittenToEnableSkip_=9223372036854775807 HOST=null
# USER=lngo
# HADOOP_USER=null
# last tool output: |null|
#
# java.io.IOException: Broken pipe
# 	at java.io.FileOutputStream.writeBytes(Native Method)
# 	at java.io.FileOutputStream.write(FileOutputStream.java:326)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:122)
# 	at java.io.BufferedOutputStream.flushBuffer(BufferedOutputStream.java:82)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:126)
# 	at java.io.DataOutputStream.write(DataOutputStream.java:107)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeUTF8(TextInputWriter.java:72)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeValue(TextInputWriter.java:51)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:106)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
# 2016-10-21 08:33:37,121 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:120)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
# 2016-10-21 08:33:37,121 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
# 2016-10-21 08:33:37,122 WARN [main] org.apache.hadoop.mapred.YarnChild: Exception running child : java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:168)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1709)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:162)
#
# 2016-10-21 08:33:37,135 WARN [main] org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Could not delete hdfs://dsci/user/lngo/intro-to-hadoop/output-movielens-01/_temporary/1/_temporary/attempt_1476193845089_0123_m_000003_1
# End of LogType:syslog

# %% [markdown]
# Can we refine the information further:
# - In a MapReduce setting, containers (often) execute the same task.

# %%
!'yarn logs -applicationId APPLICATION_ID' |

# %%
!'yarn logs -applicationId application_1476193845089_0123' | grep '^Container:'
# Out:
# 17/01/18 09:43:53 INFO impl.TimelineClientImpl: Timeline service address: http://dscim003.palmetto.clemson.edu:8188/ws/v1/timeline/
# Unable to get ApplicationState. Attempting to fetch logs directly from the filesystem.
# 17/01/18 09:43:55 INFO zlib.ZlibFactory: Successfully loaded & initialized native-zlib library
# 17/01/18 09:43:55 INFO compress.CodecPool: Got brand-new decompressor [.deflate]
# Container: container_e176_1476193845089_0123_01_000004 on dsci001.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000028 on dsci001.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000009 on dsci005.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000025 on dsci014.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000023 on dsci014.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000001 on dsci015.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000007 on dsci016.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000006 on dsci023.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000008 on dsci028.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000003 on dsci032.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000021 on dsci033.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000024 on dsci033.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000002 on dsci037.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000018 on dsci037.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000022 on dsci037.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000017 on dsci038.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000016 on dsci038.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000015 on dsci038.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000005 on dsci038.palmetto.clemson.edu_45454
# Container: container_e176_1476193845089_0123_01_000010 on dsci040.palmetto.clemson.edu_45454

# %% [markdown]
# Looking at the previous report, we can further identify container information:
#
# ```
# Container: container_XXXXXX on  YYYY.palmetto.clemson.edu_ZZZZZ
# ```
#
# - Container ID: container_XXXXXX
# - Address of node where container is placed: YYYY.palmetto.clemson.edu
#
# To request yarn to provide a more detailed log at container level, we run:
# ```
# !\
#     'yarn logs -applicationId APPLICATION_ID -containerId CONTAINER_ID --nodeAddress NODE_ADDRESS' \
#     | grep -v INFO
# ```

# %%
!\
    'yarn logs -applicationId application_1476193845089_0123 -containerId container_e176_1476193845089_0123_01_000028 --nodeAddress dsci001.palmetto.clemson.edu' \
    | grep -v INFO
# Out:
# 17/01/18 09:45:31 INFO impl.TimelineClientImpl: Timeline service address: http://dscim003.palmetto.clemson.edu:8188/ws/v1/timeline/
# Unable to get ApplicationState. Attempting to fetch logs directly from the filesystem.
# 17/01/18 09:45:33 INFO impl.TimelineClientImpl: Timeline service address: http://dscim003.palmetto.clemson.edu:8188/ws/v1/timeline/
# Unable to get logs for this container:container_e176_1476193845089_0123_01_000028for the application:application_1476193845089_0123
# Please enable the application history service. Or
# Using yarn logs -applicationId <appId> -containerId <containerId> --nodeAddress <nodeHttpAddress> to get the container logs

# %% [markdown]
# This error message gives us some insights into the mechanism of Hadoop MapReduce.
# - Where are the map and reduce python scripts located?
# - Where would the *movies.csv* file be, if the *-file* flag is used to upload this file?

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-01 \
    -file /home/lngo/intro-to-hadoop/avgRatingMapper04.py \
    -mapper avgRatingMapper04.py \
    -file /home/lngo/intro-to-hadoop/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
    -file /home/lngo/intro-to-hadoop/movielens/movies.csv

# %% [markdown]
# #### 2.1.2 Second Error!!!
#
# - HDFS is read only. Therefore, all output directories must not have existed prior to job submission
# - This can be resolved either by specifying a new output directory or deleting the existing output directory

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-02 \
    -file /home/lngo/intro-to-hadoop/avgRatingMapper04.py \
    -mapper avgRatingMapper04.py \
    -file /home/lngo/intro-to-hadoop/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
    -file /home/lngo/intro-to-hadoop/movielens/movies.csv

# %%
# !hdfs dfs -ls intro-to-hadoop/output-movielens-02

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-02/part-00000 \
    2>/dev/null | head -n 10

# %% [markdown]
# *What about the movies' genres?*
# - What is being passed from Map to Reduce?
# - Can reducer do the same thing as mapper, that is, to load in external data?

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-03 \
    -file /home/lngo/intro-to-hadoop/avgRatingMapper02.py \
    -mapper avgRatingMapper02.py \
    -file /home/lngo/intro-to-hadoop/avgRatingReducer02.py \
    -reducer avgRatingReducer02.py \
    -file /home/lngo/intro-to-hadoop/movielens/movies.csv

# %%
# !hdfs dfs -ls intro-to-hadoop/output-movielens-03

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-03/part-00000 \
    2>/dev/null | head -n 10

# %% [markdown]
# #### How does the number shuffly bytes in this example compare to the previous example?

# %% [markdown]
# ### Challenge:
#
# 1. Modify *avgRatingReducer02.py* so that only movies with averaged ratings higher than 3.75 are collected
# 2. Further enhance your modification so that not only movies with averaged ratings higher than 3.75 are collected but these movies also need to be rated at least 5000 times.

# %% [markdown]
# ### 2.2 Find genres which have the highest average ratings over the years
#
# - Identify the genres associated with a movie and its rating: Where to load *movies.csv* - Map side or Reduce side?
# - Each movie can have multiple genres. This increases the amount of Key/Value pairs being shuffled. What can we do to optimize?

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-04 \
    -file /home/lngo/intro-to-hadoop/avgGenreMapper01.py \
    -mapper avgGenreMapper01.py \
    -file /home/lngo/intro-to-hadoop/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
    -file /home/lngo/intro-to-hadoop/movielens/movies.csv

# %%
# !hdfs dfs -ls intro-to-hadoop/output-movielens-04

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-04/part-00000

# %% [markdown]
# **Principle of Big Data Computation: Reduce data movement**

# %% [markdown]
# #### 2.2.1 Optimization through in-mapper reduction of Key/Value pairs

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv 2>/dev/null \
    | head -n 10 \
    | python /home/lngo/intro-to-hadoop/avgGenreMapper02.py \

# %%
# !hdfs dfs -cat intro-to-hadoop/movielens/ratings.csv 2>/dev/null \
    | head -n 10 \
    | python /home/lngo/intro-to-hadoop/avgGenreMapper02.py \
    | sort \
    | python /home/lngo/intro-to-hadoop/avgGenreReducer01.py

# %%
# make sure that the path to movies.csv is correct inside avgGenreMapper02.py
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-05 \
    -file /home/lngo/intro-to-hadoop/avgGenreMapper02.py \
    -mapper avgGenreMapper02.py \
    -file /home/lngo/intro-to-hadoop/avgGenreReducer01.py \
    -reducer avgGenreReducer01.py \
    -file /home/lngo/intro-to-hadoop/movielens/movies.csv

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-05/part-00000

# %% [markdown]
# **How different are the number of shuffle bytes between the two jobs?**

# %% [markdown]
# #### 2.2.2 Optimization through combiner function

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/text/gutenberg-shakespeare.txt \
    -output intro-to-hadoop/output-wordcount-01 \
    -file /home/lngo/intro-to-hadoop/wordcountMapper.py \
    -mapper wordcountMapper.py \
    -file /home/lngo/intro-to-hadoop/wordcountReducer.py \
    -reducer wordcountReducer.py

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/text/gutenberg-shakespeare.txt \
    -output intro-to-hadoop/output-wordcount-02 \
    -file /home/lngo/intro-to-hadoop/wordcountMapper.py \
    -mapper wordcountMapper.py \
    -file /home/lngo/intro-to-hadoop/wordcountReducer.py \
    -reducer wordcountReducer.py \
    -combiner wordcountReducer.py

# %%
# make sure that the path to movies.csv is correct inside avgGenreMapper02.py
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-06 \
    -file /home/lngo/intro-to-hadoop/avgGenreMapper02.py \
    -mapper avgGenreMapper02.py \
    -file /home/lngo/intro-to-hadoop/avgGenreReducer01.py \
    -reducer avgGenreReducer01.py \
    -file /home/lngo/intro-to-hadoop/avgGenreCombiner.py \
    -combiner avgGenreCombiner.py \
    -file /home/lngo/intro-to-hadoop/movielens/movies.csv

# %% [markdown]
# **How different are the number of shuffle bytes between the two jobs?**

# %% [markdown]
# ### 2.3 Find users who rate movies most frequently in order to contact them for in-depth marketing analysis

# %% [markdown]
# - How do you define "frequently"?
#     - At least once per week?

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-07 \
    -file /home/lngo/intro-to-hadoop/userMapper01.py \
    -mapper userMapper01.py \
    -file /home/lngo/intro-to-hadoop/userReducer01.py \
    -reducer userReducer01.py

# %% [markdown]
# #### Yay, error!!!
#
# - You can see Yarn attemps to retry containers
# - Since these are logical errors and not physical errors, resistance is futile!
# - Yarn finally gets bored and shuts the job down ...

# %% [markdown]
# #### Challenge
#
# Get the list of containers from the failed application

# %%
!'yarn logs -applicationId application_1476193845089_0282' | grep '^Container:'

# %% [markdown]
# **Where is the error message?**

# %%
!\
    'yarn logs -applicationId application_1476193845089_0282 -containerId container_e176_1476193845089_0282_01_000010 --nodeAddress dsci014.palmetto.clemson.edu' \
    | grep -v INFO

# %% [markdown]
# **Now that you know what the error is, how can you fix it?**
# - What is the cause?

# %%
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-07-debug
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input intro-to-hadoop/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-07-debug \
    -file /home/lngo/intro-to-hadoop/userMapper01.py \
    -mapper userMapper01.py \
    -file /home/lngo/intro-to-hadoop/userDebugReducer01.py \
    -reducer userDebugReducer01.py

# %%
# !hdfs dfs -ls intro-to-hadoop/output-movielens-07-debug

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-07-debug/part-00000 2>/dev/null \
    | head -n 100

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-07-debug/part-00000 2>/dev/null \
    | wc -l

# %% [markdown]
# #### Challenge
#
# Modify the reducer to correct the above error

# %% [markdown]
# #### Challenge
#
# From 2.2, we know which genre has the highest rating. Can we enhance the user study so that only users who provide **frequent** reviews on movies contain the genre with the highest rating are selected?

# %% [markdown]
# ## <center> Final Cleanup </center>
#
# Executing the cell below will clean up all HDFS output directories created as a result of previous MapReduce programs.

# %%
# !hdfs dfs -ls intro-to-hadoop

# %%
# !hdfs dfs -rm -r intro-to-hadoop/output-wordcount
# !hdfs dfs -rm -r intro-to-hadoop/output-wordcount-01
# !hdfs dfs -rm -r intro-to-hadoop/output-wordcount-02
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-01
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-02
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-03
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-04
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-05
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-06
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-07
# !hdfs dfs -rm -r intro-to-hadoop/output-movielens-07-debug
