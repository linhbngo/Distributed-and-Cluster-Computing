# %% [markdown]
# # <center> Introduction to Hadoop MapReduce </center>

# %% [markdown]
# ## 2. Debugging Hadoop MapReduce Jobs

# %% [markdown]
# ** Data: Movie Ratings and Recommendation **
#
# An independent movie company is looking to invest in a new movie project. With limited finance, the company wants to
# analyze the reaction of audiences, particularly toward various movie genres, in order to identify beneficial
# movie project to focus on. The company relies on data collected from a publicly available recommendation service
# by [MovieLens](http://dl.acm.org/citation.cfm?id=2827872). This
# [dataset](http://files.grouplens.org/datasets/movielens/ml-10m-README.html) contains **24404096** ratings and **668953**
#  tag applications across **40110** movies. These data were created by **247753** users between January 09, 1995 and January 29, 2016. This dataset was generated on October 17, 2016.
#
# From this dataset, several analyses are possible, include the followings:
# 1.   Find movies which have the highest average ratings over the years and identify the corresponding genre.
# 2.   Find genres which have the highest average ratings over the years.
# 3.   Find users who rate movies most frequently in order to contact them for in-depth marketing analysis.
#
# These types of analyses, which are somewhat ambiguous, demand the ability to quickly process large amount of data in
# elatively short amount of time for decision support purposes. In these situations, the sizes of the data typically
# make analysis done on a single machine impossible and analysis done using a remote storage system impractical. For
# remainder of the lessons, we will learn how HDFS provides the basis to store massive amount of data and to enable
# the programming approach to analyze these data.

# %%
# !hdfs dfs -ls -h /repository/movielens
# Out:
# Found 7 items
# -rw-r--r--   2 lngo hdfs-user      9.3 K 2017-03-15 09:49 /repository/movielens/README.txt
# -rw-r--r--   2 lngo hdfs-user    317.9 M 2017-03-15 09:49 /repository/movielens/genome-scores.csv
# -rw-r--r--   2 lngo hdfs-user     17.7 K 2017-03-15 09:49 /repository/movielens/genome-tags.csv
# -rw-r--r--   2 lngo hdfs-user    839.2 K 2017-03-15 09:49 /repository/movielens/links.csv
# -rw-r--r--   2 lngo hdfs-user      1.9 M 2017-03-15 09:49 /repository/movielens/movies.csv
# -rw-r--r--   2 lngo hdfs-user    632.7 M 2017-03-15 09:49 /repository/movielens/ratings.csv
# -rw-r--r--   2 lngo hdfs-user     22.9 M 2017-03-15 09:49 /repository/movielens/tags.csv

# %% [markdown]
# ### Find movies which have the highest average ratings over the years and report their ratings and genres
#
# - Find the average ratings of all movies over the years
# - Sort the average ratings from highest to lowest
# - Report the results, augmented by genres

# %%
# !hdfs dfs -ls /repository/movielens

# %%
# !hdfs dfs -cat /repository/movielens/README.txt

# %%
# !hdfs dfs -cat /repository/movielens/links.csv \
    2>/dev/null | head -n 5
# Out:
# movieId,imdbId,tmdbId
# 1,0114709,862
# 2,0113497,8844
# 3,0113228,15602
# 4,0114885,31357

# %%
# !hdfs dfs -cat /repository/movielens/movies.csv \
    2>/dev/null | head -n 5
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv \
    2>/dev/null | head -n 5
# Out:
# userId,movieId,rating,timestamp
# 1,122,2.0,945544824
# 1,172,1.0,945544871
# 1,1221,5.0,945544788
# 1,1441,4.0,945544871

# %%
# !hdfs dfs -cat /repository/movielens/tags.csv \
    2>/dev/null | head -n 5
# Out:
# userId,movieId,tag,timestamp
# 28,63062,angelina jolie,1263047558
# 40,4973,Poetic,1436439070
# 40,117533,privacy,1436439140
# 57,356,life positive,1291771526

# %% [markdown]
# ### Note:
#
# To write a MapReduce program, you have to be able to identify the necessary (Key,Value) that can contribute to the final realization of the required results. This is the reducing phase. From this (Key,Value) pair format, you will be able to develop the mapping phase.

# %%
# %%writefile codes/avgRatingMapper01.py
#!/usr/bin/env python

import sys

for oneMovie in sys.stdin:
    oneMovie = oneMovie.strip()
    ratingInfo = oneMovie.split(",")
    movieID = ratingInfo[1]
    rating = ratingInfo[2]
    print ("%s\t%s" % (movieID, rating))
# Out:
# Writing codes/avgRatingMapper01.py

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv \
    2>/dev/null | head -n 5 | python ./codes/avgRatingMapper01.py
# Out:
# movieId	rating
# 122	2.0
# 172	1.0
# 1221	5.0
# 1441	4.0

# %% [markdown]
# #### *Do we really need the headers?*

# %%
# %%writefile codes/avgRatingMapper02.py
#!/usr/bin/env python

import sys

for oneMovie in sys.stdin:
    oneMovie = oneMovie.strip()
    ratingInfo = oneMovie.split(",")
    try:
        movieID = ratingInfo[1]
        rating = float(ratingInfo[2])
        print ("%s\t%s" % (movieID, rating))
    except ValueError:
        continue
# Out:
# Writing codes/avgRatingMapper02.py

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv \
    2>/dev/null | head -n 5 | python ./codes/avgRatingMapper02.py
# Out:
# 122	2.0
# 172	1.0
# 1221	5.0
# 1441	4.0

# %% [markdown]
# #### *The outcome is correct. Is it useful?*

# %% [markdown]
# Getting additional file

# %%
# !mkdir movielens
# !hdfs dfs -get /repository/movielens/movies.csv movielens/movies.csv

# %%
# %%writefile codes/avgRatingMapper03.py
#!/usr/bin/env python

import sys
import csv

movieFile = "./movielens/movies.csv"
movieList = {}

with open(movieFile, mode = 'r') as infile:
    reader = csv.reader(infile)
    for row in reader:
        movieList[row[0]] = {}
        movieList[row[0]]["title"] = row[1]
        movieList[row[0]]["genre"] = row[2]

for oneMovie in sys.stdin:
    oneMovie = oneMovie.strip()
    ratingInfo = oneMovie.split(",")
    try:
        movieTitle = movieList[ratingInfo[1]]["title"]
        movieGenre = movieList[ratingInfo[1]]["genre"]
        rating = float(ratingInfo[2])
        print ("%s\t%s\t%s" % (movieTitle, rating, movieGenre))
    except ValueError:
        continue
# Out:
# Writing codes/avgRatingMapper03.py

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv \
    2>/dev/null | head -n 5 | python ./codes/avgRatingMapper03.py
# Out:
# Boomerang (1992)	2.0	Comedy|Romance
# Johnny Mnemonic (1995)	1.0	Action|Sci-Fi|Thriller
# Godfather: Part II, The (1974)	5.0	Crime|Drama
# Benny & Joon (1993)	4.0	Comedy|Romance

# %% [markdown]
# #### *Test reducer:*

# %%
# %%writefile codes/avgRatingReducer01.py
#!/usr/bin/env python
import sys

current_movie = None
current_rating_sum = 0
current_rating_count = 0

for line in sys.stdin:
    line = line.strip()
    movie, rating, genre = line.split("\t", 2)
    try:
        rating = float(rating)
    except ValueError:
        continue

    if current_movie == movie:
        current_rating_sum += rating
        current_rating_count += 1
    else:
        if current_movie:
            rating_average = current_rating_sum / current_rating_count
            print ("%s\t%s\t%s" % (current_movie, rating_average, genre))    
        current_movie = movie
        current_rating_sum = rating
        current_rating_count = 1

if current_movie == movie:
    rating_average = current_rating_sum / current_rating_count
    print ("%s\t%s\t%s" % (current_movie, rating_average, genre))
# Out:
# Writing codes/avgRatingReducer01.py

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv 2>/dev/null \
    | head -n 5 \
    | python ./codes/avgRatingMapper03.py \
    | sort \
    | python ./codes/avgRatingReducer01.py
# Out:
# Benny & Joon (1993)	4.0	Comedy|Romance
# Boomerang (1992)	2.0	Crime|Drama
# Godfather: Part II, The (1974)	5.0	Action|Sci-Fi|Thriller
# Johnny Mnemonic (1995)	1.0	Action|Sci-Fi|Thriller

# %% [markdown]
# #### Non-HDFS correctness test

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv 2>/dev/null \
    | head -n 2000 \
    | python ./codes/avgRatingMapper03.py \
    | grep Matrix
# Out:
# Matrix Reloaded, The (2003)	4.0	Action|Adventure|Sci-Fi|Thriller|IMAX
# Matrix, The (1999)	3.5	Action|Sci-Fi|Thriller
# Matrix, The (1999)	3.5	Action|Sci-Fi|Thriller
# Matrix, The (1999)	4.5	Action|Sci-Fi|Thriller
# Matrix Reloaded, The (2003)	1.0	Action|Adventure|Sci-Fi|Thriller|IMAX
# Matrix, The (1999)	5.0	Action|Sci-Fi|Thriller
# Matrix Reloaded, The (2003)	5.0	Action|Adventure|Sci-Fi|Thriller|IMAX
# Matrix Revolutions, The (2003)	2.5	Action|Adventure|Sci-Fi|Thriller|IMAX
# Matrix, The (1999)	3.5	Action|Sci-Fi|Thriller

# %%
# !hdfs dfs -cat /repository/movielens/ratings.csv 2>/dev/null \
    | head -n 2000 \
    | python ./codes/avgRatingMapper03.py \
    | grep Matrix \
    | sort \
    | python ./codes/avgRatingReducer01.py
# Out:
# Matrix Reloaded, The (2003)	3.3333333333333335	Action|Adventure|Sci-Fi|Thriller|IMAX
# Matrix Revolutions, The (2003)	2.5	Action|Sci-Fi|Thriller
# Matrix, The (1999)	4.0	Action|Sci-Fi|Thriller

# %%
# Manual calculation check via python
(4.0+1.0+5.0)/3
# Out:
# 3.3333333333333335

# %% [markdown]
# #### Full execution on HDFS

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input /repository/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-01 \
    -file ./codes/avgRatingMapper03.py \
    -mapper avgRatingMapper03.py \
    -file ./codes/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
# Out:
# 17/10/06 12:46:01 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [./codes/avgRatingMapper03.py, ./codes/avgRatingReducer01.py] [/usr/hdp/2.6.0.3-8/hadoop-mapreduce/hadoop-streaming-2.7.3.2.6.0.3-8.jar] /hadoop_java_io_tmpdir/streamjob9165299252749628929.jar tmpDir=null
# 17/10/06 12:46:03 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:46:03 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:46:03 INFO hdfs.DFSClient: Created HDFS_DELEGATION_TOKEN token 14322 for lngo on ha-hdfs:dsci
# 17/10/06 12:46:03 INFO security.TokenCache: Got dt for hdfs://dsci; Kind: HDFS_DELEGATION_TOKEN, Service: ha-hdfs:dsci, Ident: (HDFS_DELEGATION_TOKEN token 14322 for lngo)
# 17/10/06 12:46:04 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 17/10/06 12:46:04 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 8787857212dae53ffae3b3113abc894e6743b4ab]
# 17/10/06 12:46:04 INFO mapred.FileInputFormat: Total input paths to process : 1
# 17/10/06 12:46:04 INFO mapreduce.JobSubmitter: number of splits:5
# 17/10/06 12:46:04 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1505269880969_0056
# 17/10/06 12:46:04 INFO mapreduce.JobSubmitter: Kind: HDFS_DELEGATION_TOKEN, Service: ha-hdfs:dsci, Ident: (HDFS_DELEGATION_TOKEN token 14322 for lngo)
# 17/10/06 12:46:05 INFO impl.TimelineClientImpl: Timeline service address: http://dscim003.palmetto.clemson.edu:8188/ws/v1/timeline/
# 17/10/06 12:46:05 INFO impl.YarnClientImpl: Submitted application application_1505269880969_0056
# 17/10/06 12:46:05 INFO mapreduce.Job: The url to track the job: http://dscim001.palmetto.clemson.edu:8088/proxy/application_1505269880969_0056/
# 17/10/06 12:46:05 INFO mapreduce.Job: Running job: job_1505269880969_0056
# 17/10/06 12:46:14 INFO mapreduce.Job: Job job_1505269880969_0056 running in uber mode : false
# 17/10/06 12:46:14 INFO mapreduce.Job:  map 0% reduce 0%
# 17/10/06 12:46:19 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000003_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:20 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000001_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:20 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000004_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:24 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000002_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:24 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000000_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:26 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000003_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:26 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000004_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:26 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000001_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:28 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000000_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:28 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000002_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:32 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000004_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:32 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000003_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:32 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000001_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:34 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000002_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:34 INFO mapreduce.Job: Task Id : attempt_1505269880969_0056_m_000000_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 17/10/06 12:46:39 INFO mapreduce.Job:  map 100% reduce 100%
# 17/10/06 12:46:39 INFO mapreduce.Job: Job job_1505269880969_0056 failed with state FAILED due to: Task failed task_1505269880969_0056_m_000001
# Job failed as tasks failed. failedMaps:1 failedReduces:0
# 17/10/06 12:46:39 INFO mapreduce.Job: Counters: 18
# 	Job Counters
# 		Failed map tasks=16
# 		Killed map tasks=4
# 		Killed reduce tasks=1
# 		Launched map tasks=20
# 		Other local map tasks=15
# 		Data-local map tasks=3
# 		Rack-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=259143
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total time spent by all map tasks (ms)=86381
# 		Total time spent by all reduce tasks (ms)=0
# 		Total vcore-milliseconds taken by all map tasks=86381
# 		Total vcore-milliseconds taken by all reduce tasks=0
# 		Total megabyte-milliseconds taken by all map tasks=1113623852
# 		Total megabyte-milliseconds taken by all reduce tasks=0
# 	Map-Reduce Framework
# 		CPU time spent (ms)=0
# 		Physical memory (bytes) snapshot=0
# 		Virtual memory (bytes) snapshot=0
# 17/10/06 12:46:39 ERROR streaming.StreamJob: Job not successful!
# Streaming Command Failed!

# %% [markdown]
# #### 2.1.1 First Error!!!
#
# Go back to the first few lines of the previously and look for the INFO line **Submitted application application_xxxx_xxxx**. Running the logs command of yarn with the provided application ID is a straightforward way to access all available log information for that application. The syntax to view yarn log is:
#
# ```
# ! yarn logs -applicationId APPLICATION_ID
# ```

# %%
# Run the yarn view log command here
# Do not run this command in a notebook browser, it will likely crash the browser
#!yarn logs -applicationId application_1476193845089_0123

# %% [markdown]
# However, this information is often massive, as it contains the aggregated logs from all tasks (map and reduce) of the job, which can be in the hundreds. The example below demonstrates this problem by displaying all the possible information of a single-task MapReduce job.
# In this example, the log of a container has three types of log (LogType):
# - stderr: Error messages from the actual task execution
# - stdout: Print out messages if the task includes them
# - syslog: Logging messages from the Hadoop MapReduce operation

# %% [markdown]
# One approach to reduce the number of possible output is to comment out all non-essential lines (lines containing **INFO**)

# %%
# !yarn logs -applicationId application_1505269880969_0056 | grep -v INFO
# Out:
# 17/10/06 12:49:36 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:49:38 INFO zlib.ZlibFactory: Successfully loaded & initialized native-zlib library
# 17/10/06 12:49:38 INFO compress.CodecPool: Got brand-new decompressor [.deflate]
# Container: container_e30_1505269880969_0056_01_000021 on dsci017.palmetto.clemson.edu_45454_1507308404811
# LogAggregationType: AGGREGATED
# =========================================================================================================
# LogType:directory.info
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:15156
# Log Contents:
# ls -l:
# total 36
# lrwxrwxrwx 1 lngo hadoop   74 Oct  6 12:46 avgRatingMapper03.py -> /data08/hadoop/yarn/local/usercache/lngo/filecache/32/avgRatingMapper03.py
# lrwxrwxrwx 1 lngo hadoop   75 Oct  6 12:46 avgRatingReducer01.py -> /data09/hadoop/yarn/local/usercache/lngo/filecache/33/avgRatingReducer01.py
# -rw------- 1 lngo hadoop  368 Oct  6 12:46 container_tokens
# lrwxrwxrwx 1 lngo hadoop  101 Oct  6 12:46 job.jar -> /data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar
# lrwxrwxrwx 1 lngo hadoop  101 Oct  6 12:46 job.xml -> /data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml
# -rwx------ 1 lngo hadoop 8342 Oct  6 12:46 launch_container.sh
# lrwxrwxrwx 1 lngo hadoop   55 Oct  6 12:46 mr-framework -> /data02/hadoop/yarn/local/filecache/10/mapreduce.tar.gz
# drwxr-s--- 2 lngo hadoop 4096 Oct  6 12:46 tmp
# find -L . -maxdepth 5 -ls:
# 31850750    4 drwxr-s---   3 lngo     hadoop       4096 Oct  6 12:46 .
# 71434463    4 -r-x--x--x   1 lngo     bigdata       674 Oct  6 12:46 ./avgRatingMapper03.py
# 31850753   12 -rwx------   1 lngo     hadoop       8342 Oct  6 12:46 ./launch_container.sh
# 128581810    4 drwx------   2 lngo     bigdata      4096 Oct  6 12:46 ./job.jar
# 128581808  108 -r-x------   1 lngo     bigdata    106928 Oct  6 12:46 ./job.jar/job.jar
# 151388371  132 -r-x------   1 lngo     bigdata    135145 Oct  6 12:46 ./job.xml
# 31850755    4 -rw-------   1 lngo     hadoop        368 Oct  6 12:46 ./container_tokens
# 31850752    4 drwxr-s---   2 lngo     hadoop       4096 Oct  6 12:46 ./tmp
# 53477513    4 drwxr-xr-x   3 yarn     hadoop       4096 May 28 21:55 ./mr-framework
# 53477518    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop
# 53477886   16 -r-xr-xr-x   1 yarn     hadoop      15753 Apr  1  2017 ./mr-framework/hadoop/NOTICE.txt
# 53477599    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/include
# 53477612    8 -r-xr-xr-x   1 yarn     hadoop       6330 Apr  1  2017 ./mr-framework/hadoop/include/Pipes.hh
# 53477614    4 -r-xr-xr-x   1 yarn     hadoop       2441 Apr  1  2017 ./mr-framework/hadoop/include/StringUtils.hh
# 53477618    8 -r-xr-xr-x   1 yarn     hadoop       4514 Apr  1  2017 ./mr-framework/hadoop/include/SerialUtils.hh
# 53477609    4 -r-xr-xr-x   1 yarn     hadoop       3319 Apr  1  2017 ./mr-framework/hadoop/include/TemplateFactory.hh
# 53477620   36 -r-xr-xr-x   1 yarn     hadoop      33361 Apr  1  2017 ./mr-framework/hadoop/include/hdfs.h
# 53477889   88 -r-xr-xr-x   1 yarn     hadoop      86424 Apr  1  2017 ./mr-framework/hadoop/LICENSE.txt
# 54657584    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/sbin
# 54657606    4 -r-xr-xr-x   1 yarn     hadoop       1260 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-balancer.sh
# 54657593    4 -r-xr-xr-x   1 yarn     hadoop       1401 Apr  1  2017 ./mr-framework/hadoop/sbin/start-dfs.cmd
# 54657610    4 -r-xr-xr-x   1 yarn     hadoop       3815 Apr  1  2017 ./mr-framework/hadoop/sbin/start-dfs.sh
# 54657589    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr  1  2017 ./mr-framework/hadoop/sbin/hdfs-config.sh
# 54657607    4 -r-xr-xr-x   1 yarn     hadoop       2226 Apr  1  2017 ./mr-framework/hadoop/sbin/slaves.sh
# 54657588    4 -r-xr-xr-x   1 yarn     hadoop       3287 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-dfs.sh
# 54657611    8 -r-xr-xr-x   1 yarn     hadoop       6546 Apr  1  2017 ./mr-framework/hadoop/sbin/hadoop-daemon.sh
# 54657599    4 -r-xr-xr-x   1 yarn     hadoop       1455 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-dfs.cmd
# 54657600    4 -r-xr-xr-x   1 yarn     hadoop       1642 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-yarn.cmd
# 54657603    4 -r-xr-xr-x   1 yarn     hadoop       2752 Apr  1  2017 ./mr-framework/hadoop/sbin/distribute-exclude.sh
# 54657591    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-yarn.sh
# 54657590    4 -r-xr-xr-x   1 yarn     hadoop       1552 Apr  1  2017 ./mr-framework/hadoop/sbin/start-all.sh
# 54657594    4 -r-xr-xr-x   1 yarn     hadoop       1770 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-all.cmd
# 54657609    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-secure-dns.sh
# 54657592    4 -r-xr-xr-x   1 yarn     hadoop       1779 Apr  1  2017 ./mr-framework/hadoop/sbin/start-all.cmd
# 54657605    4 -r-xr-xr-x   1 yarn     hadoop       1438 Apr  1  2017 ./mr-framework/hadoop/sbin/start-secure-dns.sh
# 54657602    4 -r-xr-xr-x   1 yarn     hadoop       1209 Apr  1  2017 ./mr-framework/hadoop/sbin/start-balancer.sh
# 54657596    8 -r-xr-xr-x   1 yarn     hadoop       4376 Apr  1  2017 ./mr-framework/hadoop/sbin/yarn-daemon.sh
# 54657586    4 -r-xr-xr-x   1 yarn     hadoop       2291 Apr  1  2017 ./mr-framework/hadoop/sbin/httpfs.sh
# 54657585    4 -r-xr-xr-x   1 yarn     hadoop       1441 Apr  1  2017 ./mr-framework/hadoop/sbin/hadoop-daemons.sh
# 54657601    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr  1  2017 ./mr-framework/hadoop/sbin/hdfs-config.cmd
# 54657604    8 -r-xr-xr-x   1 yarn     hadoop       4161 Apr  1  2017 ./mr-framework/hadoop/sbin/mr-jobhistory-daemon.sh
# 54657608    4 -r-xr-xr-x   1 yarn     hadoop       3630 Apr  1  2017 ./mr-framework/hadoop/sbin/kms.sh
# 54657595    4 -r-xr-xr-x   1 yarn     hadoop       1428 Apr  1  2017 ./mr-framework/hadoop/sbin/start-yarn.sh
# 54657598    4 -r-xr-xr-x   1 yarn     hadoop       1729 Apr  1  2017 ./mr-framework/hadoop/sbin/refresh-namenodes.sh
# 54657597    4 -r-xr-xr-x   1 yarn     hadoop       1543 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-all.sh
# 54657587    4 -r-xr-xr-x   1 yarn     hadoop       1571 Apr  1  2017 ./mr-framework/hadoop/sbin/start-yarn.cmd
# 54657612    4 -r-xr-xr-x   1 yarn     hadoop       1434 Apr  1  2017 ./mr-framework/hadoop/sbin/yarn-daemons.sh
# 53477883    4 -r-xr-xr-x   1 yarn     hadoop       1366 Apr  1  2017 ./mr-framework/hadoop/README.txt
# 53477696    4 drwxr-xr-x   4 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share
# 53477702    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/doc
# 53477705    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/doc/hadoop
# 53477728    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop
# 53477732    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/mapreduce
# 54526113    4 drwxr-xr-x   7 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/hdfs
# 54657449    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/tools
# 54591685    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/httpfs
# 53674116    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/kms
# 54657343    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/common
# 54592051    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/yarn
# 53477519    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/etc
# 53477521    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop
# 53477598   16 -r-xr-xr-x   1 yarn     hadoop      12302 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 53477564    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 53477555    4 -r-xr-xr-x   1 yarn     hadoop        775 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hdfs-site.xml
# 53477552    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 53477576    4 -r-xr-xr-x   1 yarn     hadoop        774 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/core-site.xml
# 53477572    4 -r-xr-xr-x   1 yarn     hadoop       2316 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/ssl-client.xml.example
# 53477535    4 -r-xr-xr-x   1 yarn     hadoop        690 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-site.xml
# 53477563    4 -r-xr-xr-x   1 yarn     hadoop         21 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-signature.secret
# 53477525    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 53477554    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 53477529    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 53477588    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 53477569    4 -r-xr-xr-x   1 yarn     hadoop       1631 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-log4j.properties
# 53477567    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/slaves
# 53477528    8 -r-xr-xr-x   1 yarn     hadoop       4529 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.sh
# 53477566    4 -r-xr-xr-x   1 yarn     hadoop        620 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-site.xml
# 53477546   12 -r-xr-xr-x   1 yarn     hadoop       9683 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-policy.xml
# 53477541    4 -r-xr-xr-x   1 yarn     hadoop       1536 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-env.sh
# 53477533    4 -r-xr-xr-x   1 yarn     hadoop       1383 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-env.sh
# 53477596    4 -r-xr-xr-x   1 yarn     hadoop        318 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/container-executor.cfg
# 53477522    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 53477531    4 -r-xr-xr-x   1 yarn     hadoop       2697 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/ssl-server.xml.example
# 53477539    4 -r-xr-xr-x   1 yarn     hadoop       2490 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics.properties
# 53477589    4 -r-xr-xr-x   1 yarn     hadoop        951 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-env.cmd
# 53477534    8 -r-xr-xr-x   1 yarn     hadoop       5511 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-site.xml
# 53477597    4 -r-xr-xr-x   1 yarn     hadoop       1527 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-env.sh
# 53477565    8 -r-xr-xr-x   1 yarn     hadoop       4567 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.sh
# 53477570    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 53477542    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 54657573    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/libexec
# 54657576    4 -r-xr-xr-x   1 yarn     hadoop       2304 Apr  1  2017 ./mr-framework/hadoop/libexec/mapred-config.sh
# 54657577    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr  1  2017 ./mr-framework/hadoop/libexec/hdfs-config.sh
# 54657575   12 -r-xr-xr-x   1 yarn     hadoop      11678 Apr  1  2017 ./mr-framework/hadoop/libexec/hadoop-config.sh
# 54657579   12 -r-xr-xr-x   1 yarn     hadoop       8270 Apr  1  2017 ./mr-framework/hadoop/libexec/hadoop-config.cmd
# 54657574    8 -r-xr-xr-x   1 yarn     hadoop       6016 Apr  1  2017 ./mr-framework/hadoop/libexec/httpfs-config.sh
# 54657582    4 -r-xr-xr-x   1 yarn     hadoop       2131 Apr  1  2017 ./mr-framework/hadoop/libexec/yarn-config.cmd
# 54657580    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr  1  2017 ./mr-framework/hadoop/libexec/hdfs-config.cmd
# 54657581    8 -r-xr-xr-x   1 yarn     hadoop       5431 Apr  1  2017 ./mr-framework/hadoop/libexec/kms-config.sh
# 54657578    4 -r-xr-xr-x   1 yarn     hadoop       1777 Apr  1  2017 ./mr-framework/hadoop/libexec/mapred-config.cmd
# 54657583    4 -r-xr-xr-x   1 yarn     hadoop       2215 Apr  1  2017 ./mr-framework/hadoop/libexec/yarn-config.sh
# 53477632    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/bin
# 53477687   12 -r-xr-xr-x   1 yarn     hadoop       8786 Apr  1  2017 ./mr-framework/hadoop/bin/hadoop.cmd
# 53477669   12 -r-xr-xr-x   1 yarn     hadoop      12069 Apr  1  2017 ./mr-framework/hadoop/bin/yarn.cmd
# 53477654   16 -r-xr-xr-x   1 yarn     hadoop      12707 Apr  1  2017 ./mr-framework/hadoop/bin/hdfs
# 53477681   12 -r-xr-xr-x   1 yarn     hadoop       8782 Apr  1  2017 ./mr-framework/hadoop/bin/hdfs.cmd
# 53477645    8 -r-xr-xr-x   1 yarn     hadoop       6448 Apr  1  2017 ./mr-framework/hadoop/bin/mapred
# 53477653    4 -r-xr-xr-x   1 yarn     hadoop        830 Apr  1  2017 ./mr-framework/hadoop/bin/kill-name-node
# 53477664    8 -r-xr-xr-x   1 yarn     hadoop       7120 Apr  1  2017 ./mr-framework/hadoop/bin/hadoop
# 53477650  132 -r-xr-xr-x   1 yarn     hadoop     134707 Apr  1  2017 ./mr-framework/hadoop/bin/container-executor
# 53477660    8 -r-xr-xr-x   1 yarn     hadoop       7465 Apr  1  2017 ./mr-framework/hadoop/bin/mapred.cmd
# 53477642    4 -r-xr-xr-x   1 yarn     hadoop        888 Apr  1  2017 ./mr-framework/hadoop/bin/kill-secondary-name-node
# 53477680   16 -r-xr-xr-x   1 yarn     hadoop      14958 Apr  1  2017 ./mr-framework/hadoop/bin/yarn
# 53477649    4 -r-xr-xr-x   1 yarn     hadoop       1857 Apr  1  2017 ./mr-framework/hadoop/bin/rcc
# 53477692  140 -r-xr-xr-x   1 yarn     hadoop     141805 Apr  1  2017 ./mr-framework/hadoop/bin/test-container-executor
# 54657613    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/lib
# 54657614    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/lib/native
# 54657615   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so.1
# 54657617  756 -r-xr-xr-x   1 yarn     hadoop     773247 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.so.1.0.0
# 54657618  572 -r-xr-xr-x   1 yarn     hadoop     582160 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadooputils.a
# 54657616  228 -r-xr-xr-x   1 yarn     hadoop     229649 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.so
# 54657615   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so
# 54657621 1288 -r-xr-xr-x   1 yarn     hadoop    1316074 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.a
# 54657615   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so.1.1.4
# 54657622  360 -r-xr-xr-x   1 yarn     hadoop     365604 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.a
# 54657617  756 -r-xr-xr-x   1 yarn     hadoop     773247 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.so
# 54657625 1456 -r-xr-xr-x   1 yarn     hadoop    1487084 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadooppipes.a
# 54657616  228 -r-xr-xr-x   1 yarn     hadoop     229649 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.so.0.0.0
# 31850748    4 -r-x------   1 lngo     bigdata       821 Oct  6 12:46 ./avgRatingReducer01.py
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
#
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:8342
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR=${HADOOP_CONF_DIR:-"/usr/hdp/current/hadoop-client/conf"}
# export STDOUT_LOGFILE_ENV="/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/stdout"
# export JAVA_HOME=${JAVA_HOME:-"/usr/lib/jvm/java"}
# export NM_HOST="dsci017.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001/*::/usr/hdp/2.6.0.3-8/tez/*:/usr/hdp/2.6.0.3-8/tez/lib/*:/usr/hdp/2.6.0.3-8/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.6.0.3-8/hadoop/lib/native:/usr/hdp/2.6.0.3-8/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021"
# export HADOOP_CLIENT_OPTS="-Xmx32768m -Xmx32768m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data02/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data03/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data04/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data05/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data06/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data07/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data08/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data10/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data11/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021,/data12/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021"
# export NM_AUX_SERVICE_mapreduce_shuffle="AAA0+gAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=
# "
# export NM_PORT="45454"
# export USER="lngo"
# export HADOOP_YARN_HOME=${HADOOP_YARN_HOME:-"/usr/hdp/current/hadoop-yarn-nodemanager"}
# export CLASSPATH="$PWD:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/*:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/lib/*:$PWD/mr-framework/hadoop/share/hadoop/common/*:$PWD/mr-framework/hadoop/share/hadoop/common/lib/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/lib/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/lib/*:/usr/hdp/2.6.0.3-8/hadoop/lib/hadoop-lzo-0.6.0.2.6.0.3-8.jar:/etc/hadoop/conf/secure:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*"
# export HADOOP_TOKEN_FILE_LOCATION="/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/container_tokens"
# export NM_AUX_SERVICE_spark_shuffle=""
# export LOCAL_USER_DIRS="/data01/hadoop/yarn/local/usercache/lngo/,/data02/hadoop/yarn/local/usercache/lngo/,/data03/hadoop/yarn/local/usercache/lngo/,/data04/hadoop/yarn/local/usercache/lngo/,/data05/hadoop/yarn/local/usercache/lngo/,/data06/hadoop/yarn/local/usercache/lngo/,/data07/hadoop/yarn/local/usercache/lngo/,/data08/hadoop/yarn/local/usercache/lngo/,/data09/hadoop/yarn/local/usercache/lngo/,/data10/hadoop/yarn/local/usercache/lngo/,/data11/hadoop/yarn/local/usercache/lngo/,/data12/hadoop/yarn/local/usercache/lngo/"
# export HOME="/home/"
# export NM_AUX_SERVICE_spark2_shuffle=""
# export CONTAINER_ID="container_e30_1505269880969_0056_01_000021"
# export MALLOC_ARENA_MAX="4"
# ln -sf "/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar" "job.jar"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data08/hadoop/yarn/local/usercache/lngo/filecache/32/avgRatingMapper03.py" "avgRatingMapper03.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data09/hadoop/yarn/local/usercache/lngo/filecache/33/avgRatingReducer01.py" "avgRatingReducer01.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data02/hadoop/yarn/local/filecache/10/mapreduce.tar.gz" "mr-framework"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml" "job.xml"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# # Creating copy of launch script
# cp "launch_container.sh" "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/launch_container.sh"
# chmod 640 "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/launch_container.sh"
# # Determining directory contents
# echo "ls -l:" 1>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/directory.info"
# ls -l 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/directory.info"
# echo "find -L . -maxdepth 5 -ls:" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/directory.info"
# find -L . -maxdepth 5 -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/directory.info"
# echo "broken symlinks(find -L . -maxdepth 5 -type l -ls):" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/directory.info"
# find -L . -maxdepth 5 -type l -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000021/directory.info"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
#
# End of LogType:launch_container.sh
#
# LogType:stderr
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:0
# Log Contents:
#
# End of LogType:stderr
#
# LogType:stdout
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:0
# Log Contents:
#
# End of LogType:stdout
#
# LogType:syslog
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:7085
# Log Contents:
# 2017-10-06 12:46:36,062 WARN [main] org.apache.hadoop.metrics2.impl.MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-maptask.properties,hadoop-metrics2.properties
# 2017-10-06 12:46:36,989 WARN [main] org.apache.hadoop.ipc.Client: Exception encountered while connecting to the server : org.apache.hadoop.ipc.RemoteException(org.apache.hadoop.ipc.StandbyException): Operation category READ is not supported in state standby
#
# End of LogType:syslog
#
# Container: container_e30_1505269880969_0056_01_000013 on dsci017.palmetto.clemson.edu_45454_1507308404811
# LogAggregationType: AGGREGATED
# =========================================================================================================
# LogType:directory.info
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:15156
# Log Contents:
# ls -l:
# total 36
# lrwxrwxrwx 1 lngo hadoop   74 Oct  6 12:46 avgRatingMapper03.py -> /data08/hadoop/yarn/local/usercache/lngo/filecache/32/avgRatingMapper03.py
# lrwxrwxrwx 1 lngo hadoop   75 Oct  6 12:46 avgRatingReducer01.py -> /data09/hadoop/yarn/local/usercache/lngo/filecache/33/avgRatingReducer01.py
# -rw------- 1 lngo hadoop  368 Oct  6 12:46 container_tokens
# lrwxrwxrwx 1 lngo hadoop  101 Oct  6 12:46 job.jar -> /data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar
# lrwxrwxrwx 1 lngo hadoop  101 Oct  6 12:46 job.xml -> /data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml
# -rwx------ 1 lngo hadoop 8342 Oct  6 12:46 launch_container.sh
# lrwxrwxrwx 1 lngo hadoop   55 Oct  6 12:46 mr-framework -> /data02/hadoop/yarn/local/filecache/10/mapreduce.tar.gz
# drwxr-s--- 2 lngo hadoop 4096 Oct  6 12:46 tmp
# find -L . -maxdepth 5 -ls:
# 31850753    4 drwxr-s---   3 lngo     hadoop       4096 Oct  6 12:46 .
# 71434463    4 -r-x------   1 lngo     bigdata       674 Oct  6 12:46 ./avgRatingMapper03.py
# 31850756   12 -rwx------   1 lngo     hadoop       8342 Oct  6 12:46 ./launch_container.sh
# 128581810    4 drwx------   2 lngo     bigdata      4096 Oct  6 12:46 ./job.jar
# 128581808  108 -r-x------   1 lngo     bigdata    106928 Oct  6 12:46 ./job.jar/job.jar
# 151388371  132 -r-x------   1 lngo     bigdata    135145 Oct  6 12:46 ./job.xml
# 31850758    4 -rw-------   1 lngo     hadoop        368 Oct  6 12:46 ./container_tokens
# 31850755    4 drwxr-s---   2 lngo     hadoop       4096 Oct  6 12:46 ./tmp
# 53477513    4 drwxr-xr-x   3 yarn     hadoop       4096 May 28 21:55 ./mr-framework
# 53477518    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop
# 53477886   16 -r-xr-xr-x   1 yarn     hadoop      15753 Apr  1  2017 ./mr-framework/hadoop/NOTICE.txt
# 53477599    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/include
# 53477612    8 -r-xr-xr-x   1 yarn     hadoop       6330 Apr  1  2017 ./mr-framework/hadoop/include/Pipes.hh
# 53477614    4 -r-xr-xr-x   1 yarn     hadoop       2441 Apr  1  2017 ./mr-framework/hadoop/include/StringUtils.hh
# 53477618    8 -r-xr-xr-x   1 yarn     hadoop       4514 Apr  1  2017 ./mr-framework/hadoop/include/SerialUtils.hh
# 53477609    4 -r-xr-xr-x   1 yarn     hadoop       3319 Apr  1  2017 ./mr-framework/hadoop/include/TemplateFactory.hh
# 53477620   36 -r-xr-xr-x   1 yarn     hadoop      33361 Apr  1  2017 ./mr-framework/hadoop/include/hdfs.h
# 53477889   88 -r-xr-xr-x   1 yarn     hadoop      86424 Apr  1  2017 ./mr-framework/hadoop/LICENSE.txt
# 54657584    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/sbin
# 54657606    4 -r-xr-xr-x   1 yarn     hadoop       1260 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-balancer.sh
# 54657593    4 -r-xr-xr-x   1 yarn     hadoop       1401 Apr  1  2017 ./mr-framework/hadoop/sbin/start-dfs.cmd
# 54657610    4 -r-xr-xr-x   1 yarn     hadoop       3815 Apr  1  2017 ./mr-framework/hadoop/sbin/start-dfs.sh
# 54657589    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr  1  2017 ./mr-framework/hadoop/sbin/hdfs-config.sh
# 54657607    4 -r-xr-xr-x   1 yarn     hadoop       2226 Apr  1  2017 ./mr-framework/hadoop/sbin/slaves.sh
# 54657588    4 -r-xr-xr-x   1 yarn     hadoop       3287 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-dfs.sh
# 54657611    8 -r-xr-xr-x   1 yarn     hadoop       6546 Apr  1  2017 ./mr-framework/hadoop/sbin/hadoop-daemon.sh
# 54657599    4 -r-xr-xr-x   1 yarn     hadoop       1455 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-dfs.cmd
# 54657600    4 -r-xr-xr-x   1 yarn     hadoop       1642 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-yarn.cmd
# 54657603    4 -r-xr-xr-x   1 yarn     hadoop       2752 Apr  1  2017 ./mr-framework/hadoop/sbin/distribute-exclude.sh
# 54657591    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-yarn.sh
# 54657590    4 -r-xr-xr-x   1 yarn     hadoop       1552 Apr  1  2017 ./mr-framework/hadoop/sbin/start-all.sh
# 54657594    4 -r-xr-xr-x   1 yarn     hadoop       1770 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-all.cmd
# 54657609    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-secure-dns.sh
# 54657592    4 -r-xr-xr-x   1 yarn     hadoop       1779 Apr  1  2017 ./mr-framework/hadoop/sbin/start-all.cmd
# 54657605    4 -r-xr-xr-x   1 yarn     hadoop       1438 Apr  1  2017 ./mr-framework/hadoop/sbin/start-secure-dns.sh
# 54657602    4 -r-xr-xr-x   1 yarn     hadoop       1209 Apr  1  2017 ./mr-framework/hadoop/sbin/start-balancer.sh
# 54657596    8 -r-xr-xr-x   1 yarn     hadoop       4376 Apr  1  2017 ./mr-framework/hadoop/sbin/yarn-daemon.sh
# 54657586    4 -r-xr-xr-x   1 yarn     hadoop       2291 Apr  1  2017 ./mr-framework/hadoop/sbin/httpfs.sh
# 54657585    4 -r-xr-xr-x   1 yarn     hadoop       1441 Apr  1  2017 ./mr-framework/hadoop/sbin/hadoop-daemons.sh
# 54657601    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr  1  2017 ./mr-framework/hadoop/sbin/hdfs-config.cmd
# 54657604    8 -r-xr-xr-x   1 yarn     hadoop       4161 Apr  1  2017 ./mr-framework/hadoop/sbin/mr-jobhistory-daemon.sh
# 54657608    4 -r-xr-xr-x   1 yarn     hadoop       3630 Apr  1  2017 ./mr-framework/hadoop/sbin/kms.sh
# 54657595    4 -r-xr-xr-x   1 yarn     hadoop       1428 Apr  1  2017 ./mr-framework/hadoop/sbin/start-yarn.sh
# 54657598    4 -r-xr-xr-x   1 yarn     hadoop       1729 Apr  1  2017 ./mr-framework/hadoop/sbin/refresh-namenodes.sh
# 54657597    4 -r-xr-xr-x   1 yarn     hadoop       1543 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-all.sh
# 54657587    4 -r-xr-xr-x   1 yarn     hadoop       1571 Apr  1  2017 ./mr-framework/hadoop/sbin/start-yarn.cmd
# 54657612    4 -r-xr-xr-x   1 yarn     hadoop       1434 Apr  1  2017 ./mr-framework/hadoop/sbin/yarn-daemons.sh
# 53477883    4 -r-xr-xr-x   1 yarn     hadoop       1366 Apr  1  2017 ./mr-framework/hadoop/README.txt
# 53477696    4 drwxr-xr-x   4 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share
# 53477702    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/doc
# 53477705    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/doc/hadoop
# 53477728    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop
# 53477732    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/mapreduce
# 54526113    4 drwxr-xr-x   7 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/hdfs
# 54657449    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/tools
# 54591685    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/httpfs
# 53674116    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/kms
# 54657343    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/common
# 54592051    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/yarn
# 53477519    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/etc
# 53477521    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop
# 53477598   16 -r-xr-xr-x   1 yarn     hadoop      12302 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 53477564    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 53477555    4 -r-xr-xr-x   1 yarn     hadoop        775 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hdfs-site.xml
# 53477552    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 53477576    4 -r-xr-xr-x   1 yarn     hadoop        774 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/core-site.xml
# 53477572    4 -r-xr-xr-x   1 yarn     hadoop       2316 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/ssl-client.xml.example
# 53477535    4 -r-xr-xr-x   1 yarn     hadoop        690 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-site.xml
# 53477563    4 -r-xr-xr-x   1 yarn     hadoop         21 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-signature.secret
# 53477525    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 53477554    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 53477529    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 53477588    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 53477569    4 -r-xr-xr-x   1 yarn     hadoop       1631 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-log4j.properties
# 53477567    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/slaves
# 53477528    8 -r-xr-xr-x   1 yarn     hadoop       4529 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.sh
# 53477566    4 -r-xr-xr-x   1 yarn     hadoop        620 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-site.xml
# 53477546   12 -r-xr-xr-x   1 yarn     hadoop       9683 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-policy.xml
# 53477541    4 -r-xr-xr-x   1 yarn     hadoop       1536 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-env.sh
# 53477533    4 -r-xr-xr-x   1 yarn     hadoop       1383 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-env.sh
# 53477596    4 -r-xr-xr-x   1 yarn     hadoop        318 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/container-executor.cfg
# 53477522    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 53477531    4 -r-xr-xr-x   1 yarn     hadoop       2697 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/ssl-server.xml.example
# 53477539    4 -r-xr-xr-x   1 yarn     hadoop       2490 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics.properties
# 53477589    4 -r-xr-xr-x   1 yarn     hadoop        951 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-env.cmd
# 53477534    8 -r-xr-xr-x   1 yarn     hadoop       5511 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-site.xml
# 53477597    4 -r-xr-xr-x   1 yarn     hadoop       1527 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-env.sh
# 53477565    8 -r-xr-xr-x   1 yarn     hadoop       4567 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.sh
# 53477570    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 53477542    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 54657573    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/libexec
# 54657576    4 -r-xr-xr-x   1 yarn     hadoop       2304 Apr  1  2017 ./mr-framework/hadoop/libexec/mapred-config.sh
# 54657577    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr  1  2017 ./mr-framework/hadoop/libexec/hdfs-config.sh
# 54657575   12 -r-xr-xr-x   1 yarn     hadoop      11678 Apr  1  2017 ./mr-framework/hadoop/libexec/hadoop-config.sh
# 54657579   12 -r-xr-xr-x   1 yarn     hadoop       8270 Apr  1  2017 ./mr-framework/hadoop/libexec/hadoop-config.cmd
# 54657574    8 -r-xr-xr-x   1 yarn     hadoop       6016 Apr  1  2017 ./mr-framework/hadoop/libexec/httpfs-config.sh
# 54657582    4 -r-xr-xr-x   1 yarn     hadoop       2131 Apr  1  2017 ./mr-framework/hadoop/libexec/yarn-config.cmd
# 54657580    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr  1  2017 ./mr-framework/hadoop/libexec/hdfs-config.cmd
# 54657581    8 -r-xr-xr-x   1 yarn     hadoop       5431 Apr  1  2017 ./mr-framework/hadoop/libexec/kms-config.sh
# 54657578    4 -r-xr-xr-x   1 yarn     hadoop       1777 Apr  1  2017 ./mr-framework/hadoop/libexec/mapred-config.cmd
# 54657583    4 -r-xr-xr-x   1 yarn     hadoop       2215 Apr  1  2017 ./mr-framework/hadoop/libexec/yarn-config.sh
# 53477632    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/bin
# 53477687   12 -r-xr-xr-x   1 yarn     hadoop       8786 Apr  1  2017 ./mr-framework/hadoop/bin/hadoop.cmd
# 53477669   12 -r-xr-xr-x   1 yarn     hadoop      12069 Apr  1  2017 ./mr-framework/hadoop/bin/yarn.cmd
# 53477654   16 -r-xr-xr-x   1 yarn     hadoop      12707 Apr  1  2017 ./mr-framework/hadoop/bin/hdfs
# 53477681   12 -r-xr-xr-x   1 yarn     hadoop       8782 Apr  1  2017 ./mr-framework/hadoop/bin/hdfs.cmd
# 53477645    8 -r-xr-xr-x   1 yarn     hadoop       6448 Apr  1  2017 ./mr-framework/hadoop/bin/mapred
# 53477653    4 -r-xr-xr-x   1 yarn     hadoop        830 Apr  1  2017 ./mr-framework/hadoop/bin/kill-name-node
# 53477664    8 -r-xr-xr-x   1 yarn     hadoop       7120 Apr  1  2017 ./mr-framework/hadoop/bin/hadoop
# 53477650  132 -r-xr-xr-x   1 yarn     hadoop     134707 Apr  1  2017 ./mr-framework/hadoop/bin/container-executor
# 53477660    8 -r-xr-xr-x   1 yarn     hadoop       7465 Apr  1  2017 ./mr-framework/hadoop/bin/mapred.cmd
# 53477642    4 -r-xr-xr-x   1 yarn     hadoop        888 Apr  1  2017 ./mr-framework/hadoop/bin/kill-secondary-name-node
# 53477680   16 -r-xr-xr-x   1 yarn     hadoop      14958 Apr  1  2017 ./mr-framework/hadoop/bin/yarn
# 53477649    4 -r-xr-xr-x   1 yarn     hadoop       1857 Apr  1  2017 ./mr-framework/hadoop/bin/rcc
# 53477692  140 -r-xr-xr-x   1 yarn     hadoop     141805 Apr  1  2017 ./mr-framework/hadoop/bin/test-container-executor
# 54657613    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/lib
# 54657614    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/lib/native
# 54657615   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so.1
# 54657617  756 -r-xr-xr-x   1 yarn     hadoop     773247 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.so.1.0.0
# 54657618  572 -r-xr-xr-x   1 yarn     hadoop     582160 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadooputils.a
# 54657616  228 -r-xr-xr-x   1 yarn     hadoop     229649 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.so
# 54657615   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so
# 54657621 1288 -r-xr-xr-x   1 yarn     hadoop    1316074 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.a
# 54657615   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so.1.1.4
# 54657622  360 -r-xr-xr-x   1 yarn     hadoop     365604 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.a
# 54657617  756 -r-xr-xr-x   1 yarn     hadoop     773247 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.so
# 54657625 1456 -r-xr-xr-x   1 yarn     hadoop    1487084 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadooppipes.a
# 54657616  228 -r-xr-xr-x   1 yarn     hadoop     229649 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.so.0.0.0
# 31850748    4 -r-x------   1 lngo     bigdata       821 Oct  6 12:46 ./avgRatingReducer01.py
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
#
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:8342
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR=${HADOOP_CONF_DIR:-"/usr/hdp/current/hadoop-client/conf"}
# export STDOUT_LOGFILE_ENV="/data12/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/stdout"
# export JAVA_HOME=${JAVA_HOME:-"/usr/lib/jvm/java"}
# export NM_HOST="dsci017.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001/*::/usr/hdp/2.6.0.3-8/tez/*:/usr/hdp/2.6.0.3-8/tez/lib/*:/usr/hdp/2.6.0.3-8/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.6.0.3-8/hadoop/lib/native:/usr/hdp/2.6.0.3-8/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data12/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013"
# export HADOOP_CLIENT_OPTS="-Xmx32768m -Xmx32768m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data02/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data03/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data04/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data05/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data06/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data07/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data08/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data10/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data11/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013,/data12/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013"
# export NM_AUX_SERVICE_mapreduce_shuffle="AAA0+gAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=
# "
# export NM_PORT="45454"
# export USER="lngo"
# export HADOOP_YARN_HOME=${HADOOP_YARN_HOME:-"/usr/hdp/current/hadoop-yarn-nodemanager"}
# export CLASSPATH="$PWD:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/*:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/lib/*:$PWD/mr-framework/hadoop/share/hadoop/common/*:$PWD/mr-framework/hadoop/share/hadoop/common/lib/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/lib/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/lib/*:/usr/hdp/2.6.0.3-8/hadoop/lib/hadoop-lzo-0.6.0.2.6.0.3-8.jar:/etc/hadoop/conf/secure:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*"
# export HADOOP_TOKEN_FILE_LOCATION="/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/container_tokens"
# export NM_AUX_SERVICE_spark_shuffle=""
# export LOCAL_USER_DIRS="/data01/hadoop/yarn/local/usercache/lngo/,/data02/hadoop/yarn/local/usercache/lngo/,/data03/hadoop/yarn/local/usercache/lngo/,/data04/hadoop/yarn/local/usercache/lngo/,/data05/hadoop/yarn/local/usercache/lngo/,/data06/hadoop/yarn/local/usercache/lngo/,/data07/hadoop/yarn/local/usercache/lngo/,/data08/hadoop/yarn/local/usercache/lngo/,/data09/hadoop/yarn/local/usercache/lngo/,/data10/hadoop/yarn/local/usercache/lngo/,/data11/hadoop/yarn/local/usercache/lngo/,/data12/hadoop/yarn/local/usercache/lngo/"
# export HOME="/home/"
# export NM_AUX_SERVICE_spark2_shuffle=""
# export CONTAINER_ID="container_e30_1505269880969_0056_01_000013"
# export MALLOC_ARENA_MAX="4"
# ln -sf "/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar" "job.jar"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data08/hadoop/yarn/local/usercache/lngo/filecache/32/avgRatingMapper03.py" "avgRatingMapper03.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data09/hadoop/yarn/local/usercache/lngo/filecache/33/avgRatingReducer01.py" "avgRatingReducer01.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data02/hadoop/yarn/local/filecache/10/mapreduce.tar.gz" "mr-framework"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml" "job.xml"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# # Creating copy of launch script
# cp "launch_container.sh" "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/launch_container.sh"
# chmod 640 "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/launch_container.sh"
# # Determining directory contents
# echo "ls -l:" 1>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/directory.info"
# ls -l 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/directory.info"
# echo "find -L . -maxdepth 5 -ls:" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/directory.info"
# find -L . -maxdepth 5 -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/directory.info"
# echo "broken symlinks(find -L . -maxdepth 5 -type l -ls):" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/directory.info"
# find -L . -maxdepth 5 -type l -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/directory.info"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
#
# End of LogType:launch_container.sh
#
# LogType:stderr
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:574
# Log Contents:
# Traceback (most recent call last):
#   File "/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000013/./avgRatingMapper03.py", line 9, in <module>
#     with open(movieFile, mode = 'r') as infile:
# IOError: [Errno 2] No such file or directory: './movielens/movies.csv'
# ...
# 19136808   16 -r-xr-xr-x   1 yarn     hadoop      12302 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 19136797    8 -r-xr-xr-x   1 yarn     hadoop       4567 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.sh
# 19136799    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/slaves
# 19136776    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 19136787    4 -r-xr-xr-x   1 yarn     hadoop        690 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-site.xml
# 19136792    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 19136783    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 19136804    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 19136782    8 -r-xr-xr-x   1 yarn     hadoop       4529 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.sh
# 19136790    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 19136796    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 19136794    4 -r-xr-xr-x   1 yarn     hadoop        775 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hdfs-site.xml
# 19136793    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 19136781    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 19136801    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 19136830   16 -r-xr-xr-x   1 yarn     hadoop      15753 Apr  1  2017 ./mr-framework/hadoop/NOTICE.txt
# 19136829    4 -r-xr-xr-x   1 yarn     hadoop       1366 Apr  1  2017 ./mr-framework/hadoop/README.txt
# 134480084    4 drwxr-s---   2 lngo     hadoop       4096 Oct  6 12:46 ./tmp
# 126025866    4 -r-x------   1 lngo     bigdata       821 Oct  6 12:46 ./avgRatingReducer01.py
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
#
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:8342
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR=${HADOOP_CONF_DIR:-"/usr/hdp/current/hadoop-client/conf"}
# export STDOUT_LOGFILE_ENV="/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/stdout"
# export JAVA_HOME=${JAVA_HOME:-"/usr/lib/jvm/java"}
# export NM_HOST="dsci039.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001/*::/usr/hdp/2.6.0.3-8/tez/*:/usr/hdp/2.6.0.3-8/tez/lib/*:/usr/hdp/2.6.0.3-8/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.6.0.3-8/hadoop/lib/native:/usr/hdp/2.6.0.3-8/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019"
# export HADOOP_CLIENT_OPTS="-Xmx32768m -Xmx32768m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data02/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data03/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data04/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data05/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data06/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data07/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data08/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data10/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data11/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019,/data12/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019"
# export NM_AUX_SERVICE_mapreduce_shuffle="AAA0+gAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=
# "
# export NM_PORT="45454"
# export USER="lngo"
# export HADOOP_YARN_HOME=${HADOOP_YARN_HOME:-"/usr/hdp/current/hadoop-yarn-nodemanager"}
# export CLASSPATH="$PWD:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/*:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/lib/*:$PWD/mr-framework/hadoop/share/hadoop/common/*:$PWD/mr-framework/hadoop/share/hadoop/common/lib/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/lib/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/lib/*:/usr/hdp/2.6.0.3-8/hadoop/lib/hadoop-lzo-0.6.0.2.6.0.3-8.jar:/etc/hadoop/conf/secure:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*"
# export HADOOP_TOKEN_FILE_LOCATION="/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/container_tokens"
# export NM_AUX_SERVICE_spark_shuffle=""
# export LOCAL_USER_DIRS="/data01/hadoop/yarn/local/usercache/lngo/,/data02/hadoop/yarn/local/usercache/lngo/,/data03/hadoop/yarn/local/usercache/lngo/,/data04/hadoop/yarn/local/usercache/lngo/,/data05/hadoop/yarn/local/usercache/lngo/,/data06/hadoop/yarn/local/usercache/lngo/,/data07/hadoop/yarn/local/usercache/lngo/,/data08/hadoop/yarn/local/usercache/lngo/,/data09/hadoop/yarn/local/usercache/lngo/,/data10/hadoop/yarn/local/usercache/lngo/,/data11/hadoop/yarn/local/usercache/lngo/,/data12/hadoop/yarn/local/usercache/lngo/"
# export HOME="/home/"
# export NM_AUX_SERVICE_spark2_shuffle=""
# export CONTAINER_ID="container_e30_1505269880969_0056_01_000019"
# export MALLOC_ARENA_MAX="4"
# ln -sf "/data06/hadoop/yarn/local/usercache/lngo/filecache/26/avgRatingMapper03.py" "avgRatingMapper03.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml" "job.xml"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data10/hadoop/yarn/local/filecache/11/mapreduce.tar.gz" "mr-framework"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar" "job.jar"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data07/hadoop/yarn/local/usercache/lngo/filecache/27/avgRatingReducer01.py" "avgRatingReducer01.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# # Creating copy of launch script
# cp "launch_container.sh" "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/launch_container.sh"
# chmod 640 "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/launch_container.sh"
# # Determining directory contents
# echo "ls -l:" 1>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/directory.info"
# ls -l 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/directory.info"
# echo "find -L . -maxdepth 5 -ls:" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/directory.info"
# find -L . -maxdepth 5 -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/directory.info"
# echo "broken symlinks(find -L . -maxdepth 5 -type l -ls):" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/directory.info"
# find -L . -maxdepth 5 -type l -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/directory.info"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
#
# End of LogType:launch_container.sh
#
# LogType:stderr
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:574
# Log Contents:
# Traceback (most recent call last):
#   File "/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000019/./avgRatingMapper03.py", line 9, in <module>
#     with open(movieFile, mode = 'r') as infile:
# IOError: [Errno 2] No such file or directory: './movielens/movies.csv'
# log4j:WARN No appenders could be found for logger (org.apache.hadoop.metrics2.impl.MetricsSystemImpl).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
#
# End of LogType:stderr
#
# LogType:stdout
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:0
# Log Contents:
#
# End of LogType:stdout
#
# LogType:syslog
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:12659
# Log Contents:
# 2017-10-06 12:46:35,888 WARN [main] org.apache.hadoop.metrics2.impl.MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-maptask.properties,hadoop-metrics2.properties
# 2017-10-06 12:46:36,809 WARN [main] org.apache.hadoop.ipc.Client: Exception encountered while connecting to the server : org.apache.hadoop.ipc.RemoteException(org.apache.hadoop.ipc.StandbyException): Operation category READ is not supported in state standby
# minRecWrittenToEnableSkip_=9223372036854775807 HOST=null
# USER=lngo
# HADOOP_USER=null
# last tool output: |null|
#
# java.io.IOException: Broken pipe
# 	at java.io.FileOutputStream.writeBytes(Native Method)
# 	at java.io.FileOutputStream.write(FileOutputStream.java:326)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:122)
# 	at java.io.BufferedOutputStream.flushBuffer(BufferedOutputStream.java:82)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:126)
# 	at java.io.DataOutputStream.write(DataOutputStream.java:107)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeUTF8(TextInputWriter.java:72)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeValue(TextInputWriter.java:51)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:106)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
# 2017-10-06 12:46:37,620 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:120)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
# 2017-10-06 12:46:37,621 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
# 2017-10-06 12:46:37,621 WARN [main] org.apache.hadoop.mapred.YarnChild: Exception running child : java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 2017-10-06 12:46:37,630 WARN [main] org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Could not delete hdfs://dsci/user/lngo/intro-to-hadoop/output-movielens-01/_temporary/1/_temporary/attempt_1505269880969_0056_m_000001_3
#
# End of LogType:syslog

# %% [markdown]
# Can we refine the information further:
# - In a MapReduce setting, containers (often) execute the same task.
# - Can we extract only message listing the Container IDs?
#
# ~~~
# !yarn logs -applicationId APPLICATION_ID | grep '^Container:'
# ~~~

# %%
# !yarn logs -applicationId application_1505269880969_0056 | grep '^Container:'
# Out:
# 17/10/06 12:50:39 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:50:41 INFO zlib.ZlibFactory: Successfully loaded & initialized native-zlib library
# 17/10/06 12:50:41 INFO compress.CodecPool: Got brand-new decompressor [.deflate]
# Container: container_e30_1505269880969_0056_01_000021 on dsci017.palmetto.clemson.edu_45454_1507308404811
# Container: container_e30_1505269880969_0056_01_000013 on dsci017.palmetto.clemson.edu_45454_1507308404811
# Container: container_e30_1505269880969_0056_01_000007 on dsci018.palmetto.clemson.edu_45454_1507308404709
# Container: container_e30_1505269880969_0056_01_000011 on dsci018.palmetto.clemson.edu_45454_1507308404709
# Container: container_e30_1505269880969_0056_01_000009 on dsci019.palmetto.clemson.edu_45454_1507308404894
# Container: container_e30_1505269880969_0056_01_000018 on dsci020.palmetto.clemson.edu_45454_1507308403987
# Container: container_e30_1505269880969_0056_01_000001 on dsci023.palmetto.clemson.edu_45454_1507308404987
# Container: container_e30_1505269880969_0056_01_000006 on dsci024.palmetto.clemson.edu_45454_1507308404632
# Container: container_e30_1505269880969_0056_01_000003 on dsci028.palmetto.clemson.edu_45454_1507308404784
# Container: container_e30_1505269880969_0056_01_000002 on dsci028.palmetto.clemson.edu_45454_1507308404784
# Container: container_e30_1505269880969_0056_01_000008 on dsci029.palmetto.clemson.edu_45454_1507308404724
# Container: container_e30_1505269880969_0056_01_000010 on dsci029.palmetto.clemson.edu_45454_1507308404724
# Container: container_e30_1505269880969_0056_01_000016 on dsci030.palmetto.clemson.edu_45454_1507308404590
# Container: container_e30_1505269880969_0056_01_000004 on dsci032.palmetto.clemson.edu_45454_1507308404584
# Container: container_e30_1505269880969_0056_01_000005 on dsci032.palmetto.clemson.edu_45454_1507308404584
# Container: container_e30_1505269880969_0056_01_000014 on dsci033.palmetto.clemson.edu_45454_1507308404598
# Container: container_e30_1505269880969_0056_01_000020 on dsci034.palmetto.clemson.edu_45454_1507308404402
# Container: container_e30_1505269880969_0056_01_000012 on dsci035.palmetto.clemson.edu_45454_1507308404608
# Container: container_e30_1505269880969_0056_01_000017 on dsci037.palmetto.clemson.edu_45454_1507308404735
# Container: container_e30_1505269880969_0056_01_000015 on dsci038.palmetto.clemson.edu_45454_1507308404650
# Container: container_e30_1505269880969_0056_01_000019 on dsci039.palmetto.clemson.edu_45454_1507308404706

# %% [markdown]
# Looking at the previous report, we can further identify container information:
#
# ```
# Container: container_XXXXXX on  YYYY.palmetto.clemson.edu_ZZZZZ
# ```
#
# - Container ID: container_XXXXXX
# - Address of node where container is placed: YYYY.palmetto.clemson.edu
#
# To request yarn to provide a more detailed log at container level, we run:
# ```
# !yarn logs -applicationId APPLICATION_ID -containerId CONTAINER_ID --nodeAddress NODE_ADDRESS \
#     | grep -v INFO
# ```

# %%
# !yarn logs -applicationId application_1505269880969_0056 \
    -containerId container_e30_1505269880969_0056_01_000012 \
    --nodeAddress dsci035.palmetto.clemson.edu \
    | grep -v INFO
# Out:
# 17/10/06 12:53:32 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:53:33 INFO zlib.ZlibFactory: Successfully loaded & initialized native-zlib library
# 17/10/06 12:53:33 INFO compress.CodecPool: Got brand-new decompressor [.deflate]
# Container: container_e30_1505269880969_0056_01_000012 on dsci035.palmetto.clemson.edu_45454_1507308404608
# LogAggregationType: AGGREGATED
# =========================================================================================================
# 17/10/06 12:53:33 INFO compress.CodecPool: Got brand-new decompressor [.deflate]
# LogType:directory.info
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:15279
# Log Contents:
# ls -l:
# total 36
# lrwxrwxrwx 1 lngo hadoop   74 Oct  6 12:46 avgRatingMapper03.py -> /data01/hadoop/yarn/local/usercache/lngo/filecache/28/avgRatingMapper03.py
# lrwxrwxrwx 1 lngo hadoop   75 Oct  6 12:46 avgRatingReducer01.py -> /data02/hadoop/yarn/local/usercache/lngo/filecache/29/avgRatingReducer01.py
# -rw------- 1 lngo hadoop  368 Oct  6 12:46 container_tokens
# lrwxrwxrwx 1 lngo hadoop  101 Oct  6 12:46 job.jar -> /data03/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar
# lrwxrwxrwx 1 lngo hadoop  101 Oct  6 12:46 job.xml -> /data04/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml
# -rwx------ 1 lngo hadoop 8342 Oct  6 12:46 launch_container.sh
# lrwxrwxrwx 1 lngo hadoop   55 Oct  6 12:46 mr-framework -> /data11/hadoop/yarn/local/filecache/10/mapreduce.tar.gz
# drwxr-s--- 2 lngo hadoop 4096 Oct  6 12:46 tmp
# find -L . -maxdepth 5 -ls:
# 182386934    4 drwxr-s---   3 lngo     hadoop       4096 Oct  6 12:46 .
# 43319448    4 drwx------   2 lngo     bigdata      4096 Oct  6 12:46 ./job.jar
# 43319446  108 -r-x------   1 lngo     bigdata    106928 Oct  6 12:46 ./job.jar/job.jar
# 174522406    4 drwxr-xr-x   3 yarn     hadoop       4096 May 28 21:26 ./mr-framework
# 174522407    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop
# 175506061    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/lib
# 175506062    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/lib/native
# 175506063   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so
# 175506070  360 -r-xr-xr-x   1 yarn     hadoop     365604 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.a
# 175506065  756 -r-xr-xr-x   1 yarn     hadoop     773247 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.so
# 175506064  228 -r-xr-xr-x   1 yarn     hadoop     229649 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.so
# 175506063   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so.1
# 175506073 1456 -r-xr-xr-x   1 yarn     hadoop    1487084 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadooppipes.a
# 175506066  572 -r-xr-xr-x   1 yarn     hadoop     582160 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadooputils.a
# 175506069 1288 -r-xr-xr-x   1 yarn     hadoop    1316074 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.a
# 175506063   20 -r-xr-xr-x   1 yarn     hadoop      19848 Apr  1  2017 ./mr-framework/hadoop/lib/native/libsnappy.so.1.1.4
# 175506065  756 -r-xr-xr-x   1 yarn     hadoop     773247 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhadoop.so.1.0.0
# 175506064  228 -r-xr-xr-x   1 yarn     hadoop     229649 Apr  1  2017 ./mr-framework/hadoop/lib/native/libhdfs.so.0.0.0
# 174522687   16 -r-xr-xr-x   1 yarn     hadoop      15753 Apr  1  2017 ./mr-framework/hadoop/NOTICE.txt
# 174522408    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/etc
# 174522411    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop
# 174522574   12 -r-xr-xr-x   1 yarn     hadoop       9683 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-policy.xml
# 174522577    4 -r-xr-xr-x   1 yarn     hadoop        775 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hdfs-site.xml
# 174522590    4 -r-xr-xr-x   1 yarn     hadoop        318 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/container-executor.cfg
# 174522592   16 -r-xr-xr-x   1 yarn     hadoop      12302 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/log4j.properties
# 174522580    8 -r-xr-xr-x   1 yarn     hadoop       4567 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.sh
# 174522416    4 -r-xr-xr-x   1 yarn     hadoop       1657 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-log4j.properties
# 174522581    4 -r-xr-xr-x   1 yarn     hadoop        620 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-site.xml
# 174522573    4 -r-xr-xr-x   1 yarn     hadoop       3518 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-acls.xml
# 174522576    8 -r-xr-xr-x   1 yarn     hadoop       4113 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-queues.xml.template
# 174522582    4 -r-xr-xr-x   1 yarn     hadoop         10 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/slaves
# 174522586    4 -r-xr-xr-x   1 yarn     hadoop       2316 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/ssl-client.xml.example
# 174522562    8 -r-xr-xr-x   1 yarn     hadoop       4529 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.sh
# 174522588    8 -r-xr-xr-x   1 yarn     hadoop       4436 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/capacity-scheduler.xml
# 174522584    4 -r-xr-xr-x   1 yarn     hadoop       2598 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics2.properties
# 174522578    4 -r-xr-xr-x   1 yarn     hadoop         21 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-signature.secret
# 174522567    4 -r-xr-xr-x   1 yarn     hadoop       2697 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/ssl-server.xml.example
# 174522579    4 -r-xr-xr-x   1 yarn     hadoop       1335 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/configuration.xsl
# 174522571    4 -r-xr-xr-x   1 yarn     hadoop       2490 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-metrics.properties
# 174522563    4 -r-xr-xr-x   1 yarn     hadoop       2250 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-env.cmd
# 174522575    4 -r-xr-xr-x   1 yarn     hadoop        758 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-site.xml.template
# 174522583    4 -r-xr-xr-x   1 yarn     hadoop       1631 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-log4j.properties
# 174522557    4 -r-xr-xr-x   1 yarn     hadoop       3979 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/hadoop-env.cmd
# 174522591    4 -r-xr-xr-x   1 yarn     hadoop       1527 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-env.sh
# 174522568    4 -r-xr-xr-x   1 yarn     hadoop       1383 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-env.sh
# 174522572    4 -r-xr-xr-x   1 yarn     hadoop       1536 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/httpfs-env.sh
# 174522589    4 -r-xr-xr-x   1 yarn     hadoop        951 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/mapred-env.cmd
# 174522587    4 -r-xr-xr-x   1 yarn     hadoop        774 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/core-site.xml
# 174522569    8 -r-xr-xr-x   1 yarn     hadoop       5511 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/kms-site.xml
# 174522570    4 -r-xr-xr-x   1 yarn     hadoop        690 Apr  1  2017 ./mr-framework/hadoop/etc/hadoop/yarn-site.xml
# 174522688   88 -r-xr-xr-x   1 yarn     hadoop      86424 Apr  1  2017 ./mr-framework/hadoop/LICENSE.txt
# 174522601    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/bin
# 174522627    4 -r-xr-xr-x   1 yarn     hadoop       1857 Apr  1  2017 ./mr-framework/hadoop/bin/rcc
# 174522630   16 -r-xr-xr-x   1 yarn     hadoop      12707 Apr  1  2017 ./mr-framework/hadoop/bin/hdfs
# 174522623    8 -r-xr-xr-x   1 yarn     hadoop       6448 Apr  1  2017 ./mr-framework/hadoop/bin/mapred
# 174522679   12 -r-xr-xr-x   1 yarn     hadoop       8786 Apr  1  2017 ./mr-framework/hadoop/bin/hadoop.cmd
# 174522636    8 -r-xr-xr-x   1 yarn     hadoop       7465 Apr  1  2017 ./mr-framework/hadoop/bin/mapred.cmd
# 174522602    4 -r-xr-xr-x   1 yarn     hadoop        888 Apr  1  2017 ./mr-framework/hadoop/bin/kill-secondary-name-node
# 174522673   12 -r-xr-xr-x   1 yarn     hadoop      12069 Apr  1  2017 ./mr-framework/hadoop/bin/yarn.cmd
# 174522678   12 -r-xr-xr-x   1 yarn     hadoop       8782 Apr  1  2017 ./mr-framework/hadoop/bin/hdfs.cmd
# 174522637    8 -r-xr-xr-x   1 yarn     hadoop       7120 Apr  1  2017 ./mr-framework/hadoop/bin/hadoop
# 174522680  140 -r-xr-xr-x   1 yarn     hadoop     141805 Apr  1  2017 ./mr-framework/hadoop/bin/test-container-executor
# 174522674   16 -r-xr-xr-x   1 yarn     hadoop      14958 Apr  1  2017 ./mr-framework/hadoop/bin/yarn
# 174522629    4 -r-xr-xr-x   1 yarn     hadoop        830 Apr  1  2017 ./mr-framework/hadoop/bin/kill-name-node
# 174522628  132 -r-xr-xr-x   1 yarn     hadoop     134707 Apr  1  2017 ./mr-framework/hadoop/bin/container-executor
# 174522681    4 drwxr-xr-x   4 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share
# 174588126    4 drwxr-xr-x   9 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop
# 175177804    4 drwxr-xr-x   7 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/hdfs
# 175505702    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/common
# 175505897    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/tools
# 174653651    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/mapreduce
# 175505537    4 drwxr-xr-x   5 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/yarn
# 175177913    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/httpfs
# 174719266    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/hadoop/kms
# 174522682    4 drwxr-xr-x   3 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/doc
# 174522683    4 drwxr-xr-x   6 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/share/doc/hadoop
# 174522686    4 -r-xr-xr-x   1 yarn     hadoop       1366 Apr  1  2017 ./mr-framework/hadoop/README.txt
# 174522593    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/include
# 174522597    4 -r-xr-xr-x   1 yarn     hadoop       2441 Apr  1  2017 ./mr-framework/hadoop/include/StringUtils.hh
# 174522596    8 -r-xr-xr-x   1 yarn     hadoop       6330 Apr  1  2017 ./mr-framework/hadoop/include/Pipes.hh
# 174522600   36 -r-xr-xr-x   1 yarn     hadoop      33361 Apr  1  2017 ./mr-framework/hadoop/include/hdfs.h
# 174522599    8 -r-xr-xr-x   1 yarn     hadoop       4514 Apr  1  2017 ./mr-framework/hadoop/include/SerialUtils.hh
# 174522595    4 -r-xr-xr-x   1 yarn     hadoop       3319 Apr  1  2017 ./mr-framework/hadoop/include/TemplateFactory.hh
# 175506032    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/sbin
# 175506056    4 -r-xr-xr-x   1 yarn     hadoop       3630 Apr  1  2017 ./mr-framework/hadoop/sbin/kms.sh
# 175506038    4 -r-xr-xr-x   1 yarn     hadoop       1552 Apr  1  2017 ./mr-framework/hadoop/sbin/start-all.sh
# 175506033    4 -r-xr-xr-x   1 yarn     hadoop       1441 Apr  1  2017 ./mr-framework/hadoop/sbin/hadoop-daemons.sh
# 175506054    4 -r-xr-xr-x   1 yarn     hadoop       1260 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-balancer.sh
# 175506055    4 -r-xr-xr-x   1 yarn     hadoop       2226 Apr  1  2017 ./mr-framework/hadoop/sbin/slaves.sh
# 175506052    8 -r-xr-xr-x   1 yarn     hadoop       4161 Apr  1  2017 ./mr-framework/hadoop/sbin/mr-jobhistory-daemon.sh
# 175506043    4 -r-xr-xr-x   1 yarn     hadoop       1428 Apr  1  2017 ./mr-framework/hadoop/sbin/start-yarn.sh
# 175506040    4 -r-xr-xr-x   1 yarn     hadoop       1779 Apr  1  2017 ./mr-framework/hadoop/sbin/start-all.cmd
# 175506034    4 -r-xr-xr-x   1 yarn     hadoop       2291 Apr  1  2017 ./mr-framework/hadoop/sbin/httpfs.sh
# 175506047    4 -r-xr-xr-x   1 yarn     hadoop       1455 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-dfs.cmd
# 175506058    4 -r-xr-xr-x   1 yarn     hadoop       3815 Apr  1  2017 ./mr-framework/hadoop/sbin/start-dfs.sh
# 175506036    4 -r-xr-xr-x   1 yarn     hadoop       3287 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-dfs.sh
# 175506037    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr  1  2017 ./mr-framework/hadoop/sbin/hdfs-config.sh
# 175506048    4 -r-xr-xr-x   1 yarn     hadoop       1642 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-yarn.cmd
# 175506050    4 -r-xr-xr-x   1 yarn     hadoop       1209 Apr  1  2017 ./mr-framework/hadoop/sbin/start-balancer.sh
# 175506060    4 -r-xr-xr-x   1 yarn     hadoop       1434 Apr  1  2017 ./mr-framework/hadoop/sbin/yarn-daemons.sh
# 175506046    4 -r-xr-xr-x   1 yarn     hadoop       1729 Apr  1  2017 ./mr-framework/hadoop/sbin/refresh-namenodes.sh
# 175506041    4 -r-xr-xr-x   1 yarn     hadoop       1401 Apr  1  2017 ./mr-framework/hadoop/sbin/start-dfs.cmd
# 175506049    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr  1  2017 ./mr-framework/hadoop/sbin/hdfs-config.cmd
# 175506057    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-secure-dns.sh
# 175506042    4 -r-xr-xr-x   1 yarn     hadoop       1770 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-all.cmd
# 175506039    4 -r-xr-xr-x   1 yarn     hadoop       1421 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-yarn.sh
# 175506053    4 -r-xr-xr-x   1 yarn     hadoop       1438 Apr  1  2017 ./mr-framework/hadoop/sbin/start-secure-dns.sh
# 175506035    4 -r-xr-xr-x   1 yarn     hadoop       1571 Apr  1  2017 ./mr-framework/hadoop/sbin/start-yarn.cmd
# 175506059    8 -r-xr-xr-x   1 yarn     hadoop       6546 Apr  1  2017 ./mr-framework/hadoop/sbin/hadoop-daemon.sh
# 175506051    4 -r-xr-xr-x   1 yarn     hadoop       2752 Apr  1  2017 ./mr-framework/hadoop/sbin/distribute-exclude.sh
# 175506045    4 -r-xr-xr-x   1 yarn     hadoop       1543 Apr  1  2017 ./mr-framework/hadoop/sbin/stop-all.sh
# 175506044    8 -r-xr-xr-x   1 yarn     hadoop       4376 Apr  1  2017 ./mr-framework/hadoop/sbin/yarn-daemon.sh
# 175506021    4 drwxr-xr-x   2 yarn     hadoop       4096 Apr  1  2017 ./mr-framework/hadoop/libexec
# 175506023   12 -r-xr-xr-x   1 yarn     hadoop      11678 Apr  1  2017 ./mr-framework/hadoop/libexec/hadoop-config.sh
# 175506027   12 -r-xr-xr-x   1 yarn     hadoop       8270 Apr  1  2017 ./mr-framework/hadoop/libexec/hadoop-config.cmd
# 175506029    8 -r-xr-xr-x   1 yarn     hadoop       5431 Apr  1  2017 ./mr-framework/hadoop/libexec/kms-config.sh
# 175506030    4 -r-xr-xr-x   1 yarn     hadoop       2131 Apr  1  2017 ./mr-framework/hadoop/libexec/yarn-config.cmd
# 175506024    4 -r-xr-xr-x   1 yarn     hadoop       2304 Apr  1  2017 ./mr-framework/hadoop/libexec/mapred-config.sh
# 175506025    4 -r-xr-xr-x   1 yarn     hadoop       1508 Apr  1  2017 ./mr-framework/hadoop/libexec/hdfs-config.sh
# 175506026    4 -r-xr-xr-x   1 yarn     hadoop       1777 Apr  1  2017 ./mr-framework/hadoop/libexec/mapred-config.cmd
# 175506028    4 -r-xr-xr-x   1 yarn     hadoop       1640 Apr  1  2017 ./mr-framework/hadoop/libexec/hdfs-config.cmd
# 175506031    4 -r-xr-xr-x   1 yarn     hadoop       2215 Apr  1  2017 ./mr-framework/hadoop/libexec/yarn-config.sh
# 175506022    8 -r-xr-xr-x   1 yarn     hadoop       6016 Apr  1  2017 ./mr-framework/hadoop/libexec/httpfs-config.sh
# 82116843    4 -r-x------   1 lngo     bigdata       674 Oct  6 12:46 ./avgRatingMapper03.py
# 182386936    4 drwxr-s---   2 lngo     hadoop       4096 Oct  6 12:46 ./tmp
# 182386937   12 -rwx------   1 lngo     hadoop       8342 Oct  6 12:46 ./launch_container.sh
# 182386938    4 -rw-------   1 lngo     hadoop        368 Oct  6 12:46 ./container_tokens
# 129433812    4 -r-x------   1 lngo     bigdata       821 Oct  6 12:46 ./avgRatingReducer01.py
# 166789129  132 -r-x------   1 lngo     bigdata    135145 Oct  6 12:46 ./job.xml
# broken symlinks(find -L . -maxdepth 5 -type l -ls):
#
# End of LogType:directory.info
#
# LogType:launch_container.sh
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:8342
# Log Contents:
# #!/bin/bash
#
# export HADOOP_CONF_DIR=${HADOOP_CONF_DIR:-"/usr/hdp/current/hadoop-client/conf"}
# export STDOUT_LOGFILE_ENV="/data11/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/stdout"
# export JAVA_HOME=${JAVA_HOME:-"/usr/lib/jvm/java"}
# export NM_HOST="dsci035.palmetto.clemson.edu"
# export HADOOP_CLASSPATH="$PWD:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000001/*::/usr/hdp/2.6.0.3-8/tez/*:/usr/hdp/2.6.0.3-8/tez/lib/*:/usr/hdp/2.6.0.3-8/tez/conf"
# export LD_LIBRARY_PATH="$PWD:/usr/hdp/2.6.0.3-8/hadoop/lib/native:/usr/hdp/2.6.0.3-8/hadoop/lib/native/Linux-amd64-64"
# export STDERR_LOGFILE_ENV="/data11/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/stderr"
# export LOGNAME="lngo"
# export JVM_PID="$$"
# export PWD="/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012"
# export HADOOP_CLIENT_OPTS="-Xmx32768m -Xmx32768m  "
# export LOCAL_DIRS="/data01/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data02/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data05/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data06/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data07/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data08/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data09/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data10/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056,/data12/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056"
# export SHELL="/bin/bash"
# export NM_HTTP_PORT="8042"
# export LOG_DIRS="/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data02/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data03/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data04/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data05/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data06/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data07/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data08/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data09/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data10/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data11/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012,/data12/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012"
# export NM_AUX_SERVICE_mapreduce_shuffle="AAA0+gAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=
# "
# export NM_PORT="45454"
# export USER="lngo"
# export HADOOP_YARN_HOME=${HADOOP_YARN_HOME:-"/usr/hdp/current/hadoop-yarn-nodemanager"}
# export CLASSPATH="$PWD:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/*:$PWD/mr-framework/hadoop/share/hadoop/mapreduce/lib/*:$PWD/mr-framework/hadoop/share/hadoop/common/*:$PWD/mr-framework/hadoop/share/hadoop/common/lib/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/*:$PWD/mr-framework/hadoop/share/hadoop/yarn/lib/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/*:$PWD/mr-framework/hadoop/share/hadoop/hdfs/lib/*:/usr/hdp/2.6.0.3-8/hadoop/lib/hadoop-lzo-0.6.0.2.6.0.3-8.jar:/etc/hadoop/conf/secure:job.jar/job.jar:job.jar/classes/:job.jar/lib/*:$PWD/*"
# export HADOOP_TOKEN_FILE_LOCATION="/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/container_tokens"
# export NM_AUX_SERVICE_spark_shuffle=""
# export LOCAL_USER_DIRS="/data01/hadoop/yarn/local/usercache/lngo/,/data02/hadoop/yarn/local/usercache/lngo/,/data03/hadoop/yarn/local/usercache/lngo/,/data04/hadoop/yarn/local/usercache/lngo/,/data05/hadoop/yarn/local/usercache/lngo/,/data06/hadoop/yarn/local/usercache/lngo/,/data07/hadoop/yarn/local/usercache/lngo/,/data08/hadoop/yarn/local/usercache/lngo/,/data09/hadoop/yarn/local/usercache/lngo/,/data10/hadoop/yarn/local/usercache/lngo/,/data11/hadoop/yarn/local/usercache/lngo/,/data12/hadoop/yarn/local/usercache/lngo/"
# export HOME="/home/"
# export NM_AUX_SERVICE_spark2_shuffle=""
# export CONTAINER_ID="container_e30_1505269880969_0056_01_000012"
# export MALLOC_ARENA_MAX="4"
# ln -sf "/data01/hadoop/yarn/local/usercache/lngo/filecache/28/avgRatingMapper03.py" "avgRatingMapper03.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data02/hadoop/yarn/local/usercache/lngo/filecache/29/avgRatingReducer01.py" "avgRatingReducer01.py"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data04/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/11/job.xml" "job.xml"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data11/hadoop/yarn/local/filecache/10/mapreduce.tar.gz" "mr-framework"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# ln -sf "/data03/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/filecache/10/job.jar" "job.jar"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
# # Creating copy of launch script
# cp "launch_container.sh" "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/launch_container.sh"
# chmod 640 "/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/launch_container.sh"
# # Determining directory contents
# echo "ls -l:" 1>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/directory.info"
# ls -l 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/directory.info"
# echo "find -L . -maxdepth 5 -ls:" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/directory.info"
# find -L . -maxdepth 5 -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/directory.info"
# echo "broken symlinks(find -L . -maxdepth 5 -type l -ls):" 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/directory.info"
# find -L . -maxdepth 5 -type l -ls 1>>"/data01/hadoop/yarn/log/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/directory.info"
# hadoop_shell_errorcode=$?
# if [ $hadoop_shell_errorcode -ne 0 ]
# then
#   exit $hadoop_shell_errorcode
# fi
#
# End of LogType:launch_container.sh
#
# LogType:stderr
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:574
# Log Contents:
# Traceback (most recent call last):
#   File "/data11/hadoop/yarn/local/usercache/lngo/appcache/application_1505269880969_0056/container_e30_1505269880969_0056_01_000012/./avgRatingMapper03.py", line 9, in <module>
#     with open(movieFile, mode = 'r') as infile:
# IOError: [Errno 2] No such file or directory: './movielens/movies.csv'
# log4j:WARN No appenders could be found for logger (org.apache.hadoop.metrics2.impl.MetricsSystemImpl).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
#
# End of LogType:stderr
#
# LogType:stdout
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:0
# Log Contents:
#
# End of LogType:stdout
#
# LogType:syslog
# Log Upload Time:Fri Oct 06 12:46:44 -0400 2017
# LogLength:12659
# Log Contents:
# 2017-10-06 12:46:29,794 WARN [main] org.apache.hadoop.metrics2.impl.MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-maptask.properties,hadoop-metrics2.properties
# 2017-10-06 12:46:30,693 WARN [main] org.apache.hadoop.ipc.Client: Exception encountered while connecting to the server : org.apache.hadoop.ipc.RemoteException(org.apache.hadoop.ipc.StandbyException): Operation category READ is not supported in state standby
# minRecWrittenToEnableSkip_=9223372036854775807 HOST=null
# USER=lngo
# HADOOP_USER=null
# last tool output: |null|
#
# java.io.IOException: Broken pipe
# 	at java.io.FileOutputStream.writeBytes(Native Method)
# 	at java.io.FileOutputStream.write(FileOutputStream.java:326)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:122)
# 	at java.io.BufferedOutputStream.flushBuffer(BufferedOutputStream.java:82)
# 	at java.io.BufferedOutputStream.write(BufferedOutputStream.java:126)
# 	at java.io.DataOutputStream.write(DataOutputStream.java:107)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeUTF8(TextInputWriter.java:72)
# 	at org.apache.hadoop.streaming.io.TextInputWriter.writeValue(TextInputWriter.java:51)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:106)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
# 2017-10-06 12:46:31,513 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.map(PipeMapper.java:120)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:54)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
# 2017-10-06 12:46:31,513 WARN [main] org.apache.hadoop.streaming.PipeMapRed: java.io.IOException: Stream closed
# java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
# 2017-10-06 12:46:31,514 WARN [main] org.apache.hadoop.mapred.YarnChild: Exception running child : java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:322)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:535)
# 	at org.apache.hadoop.streaming.PipeMapper.close(PipeMapper.java:130)
# 	at org.apache.hadoop.mapred.MapRunner.run(MapRunner.java:61)
# 	at org.apache.hadoop.streaming.PipeMapRunner.run(PipeMapRunner.java:34)
# 	at org.apache.hadoop.mapred.MapTask.runOldMapper(MapTask.java:453)
# 	at org.apache.hadoop.mapred.MapTask.run(MapTask.java:343)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:170)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1866)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:164)
#
# 2017-10-06 12:46:31,521 WARN [main] org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Could not delete hdfs://dsci/user/lngo/intro-to-hadoop/output-movielens-01/_temporary/1/_temporary/attempt_1505269880969_0056_m_000003_2
#
# End of LogType:syslog

# %% [markdown]
# This error message gives us some insights into the mechanism of Hadoop MapReduce.
# - Where are the map and reduce python scripts located?
# - Where would the *movies.csv* file be, if the *-file* flag is used to upload this file?

# %%
# %%writefile codes/avgRatingMapper04.py
#!/usr/bin/env python

import sys
import csv

movieFile = "./movies.csv"
movieList = {}

with open(movieFile, mode = 'r') as infile:
    reader = csv.reader(infile)
    for row in reader:
        movieList[row[0]] = {}
        movieList[row[0]]["title"] = row[1]
        movieList[row[0]]["genre"] = row[2]

for oneMovie in sys.stdin:
    oneMovie = oneMovie.strip()
    ratingInfo = oneMovie.split(",")
    try:
        movieTitle = movieList[ratingInfo[1]]["title"]
        movieGenre = movieList[ratingInfo[1]]["genre"]
        rating = float(ratingInfo[2])
        print ("%s\t%s\t%s" % (movieTitle, rating, movieGenre))
    except ValueError:
        continue
# Out:
# Writing codes/avgRatingMapper04.py

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input /repository/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-01 \
    -file ./codes/avgRatingMapper04.py \
    -mapper avgRatingMapper04.py \
    -file ./codes/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
    -file ./movielens/movies.csv
# Out:
# 17/10/06 12:56:09 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [./codes/avgRatingMapper04.py, ./codes/avgRatingReducer01.py, ./movielens/movies.csv] [/usr/hdp/2.6.0.3-8/hadoop-mapreduce/hadoop-streaming-2.7.3.2.6.0.3-8.jar] /hadoop_java_io_tmpdir/streamjob512904205931449469.jar tmpDir=null
# 17/10/06 12:56:11 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:56:11 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:56:12 INFO hdfs.DFSClient: Created HDFS_DELEGATION_TOKEN token 14333 for lngo on ha-hdfs:dsci
# 17/10/06 12:56:12 INFO security.TokenCache: Got dt for hdfs://dsci; Kind: HDFS_DELEGATION_TOKEN, Service: ha-hdfs:dsci, Ident: (HDFS_DELEGATION_TOKEN token 14333 for lngo)
# 17/10/06 12:56:12 ERROR streaming.StreamJob: Error Launching job : Output directory hdfs://dsci/user/lngo/intro-to-hadoop/output-movielens-01 already exists
# Streaming Command Failed!

# %% [markdown]
# #### 2.1.2 Second Error!!!
#
# - HDFS is read only. Therefore, all output directories must not have existed prior to job submission
# - This can be resolved either by specifying a new output directory or deleting the existing output directory

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input /repository/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-02 \
    -file ./codes/avgRatingMapper04.py \
    -mapper avgRatingMapper04.py \
    -file ./codes/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
    -file ./movielens/movies.csv
# Out:
# 17/10/06 12:56:52 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [./codes/avgRatingMapper04.py, ./codes/avgRatingReducer01.py, ./movielens/movies.csv] [/usr/hdp/2.6.0.3-8/hadoop-mapreduce/hadoop-streaming-2.7.3.2.6.0.3-8.jar] /hadoop_java_io_tmpdir/streamjob5078678851774131449.jar tmpDir=null
# 17/10/06 12:56:54 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:56:55 INFO client.AHSProxy: Connecting to Application History server at dscim003.palmetto.clemson.edu/10.125.8.215:10200
# 17/10/06 12:56:55 INFO hdfs.DFSClient: Created HDFS_DELEGATION_TOKEN token 14338 for lngo on ha-hdfs:dsci
# 17/10/06 12:56:55 INFO security.TokenCache: Got dt for hdfs://dsci; Kind: HDFS_DELEGATION_TOKEN, Service: ha-hdfs:dsci, Ident: (HDFS_DELEGATION_TOKEN token 14338 for lngo)
# 17/10/06 12:56:56 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# 17/10/06 12:56:56 INFO lzo.LzoCodec: Successfully loaded & initialized native-lzo library [hadoop-lzo rev 8787857212dae53ffae3b3113abc894e6743b4ab]
# 17/10/06 12:56:56 INFO mapred.FileInputFormat: Total input paths to process : 1
# 17/10/06 12:56:56 INFO mapreduce.JobSubmitter: number of splits:5
# 17/10/06 12:56:56 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1505269880969_0066
# 17/10/06 12:56:56 INFO mapreduce.JobSubmitter: Kind: HDFS_DELEGATION_TOKEN, Service: ha-hdfs:dsci, Ident: (HDFS_DELEGATION_TOKEN token 14338 for lngo)
# 17/10/06 12:56:57 INFO impl.TimelineClientImpl: Timeline service address: http://dscim003.palmetto.clemson.edu:8188/ws/v1/timeline/
# 17/10/06 12:56:57 INFO impl.YarnClientImpl: Submitted application application_1505269880969_0066
# 17/10/06 12:56:57 INFO mapreduce.Job: The url to track the job: http://dscim001.palmetto.clemson.edu:8088/proxy/application_1505269880969_0066/
# 17/10/06 12:56:57 INFO mapreduce.Job: Running job: job_1505269880969_0066
# 17/10/06 12:57:03 INFO mapreduce.Job: Job job_1505269880969_0066 running in uber mode : false
# 17/10/06 12:57:03 INFO mapreduce.Job:  map 0% reduce 0%
# 17/10/06 12:57:16 INFO mapreduce.Job:  map 32% reduce 0%
# 17/10/06 12:57:19 INFO mapreduce.Job:  map 51% reduce 0%
# 17/10/06 12:57:22 INFO mapreduce.Job:  map 66% reduce 0%
# 17/10/06 12:57:25 INFO mapreduce.Job:  map 67% reduce 0%
# 17/10/06 12:57:27 INFO mapreduce.Job:  map 73% reduce 0%
# 17/10/06 12:57:28 INFO mapreduce.Job:  map 80% reduce 0%
# 17/10/06 12:57:29 INFO mapreduce.Job:  map 87% reduce 0%
# 17/10/06 12:57:30 INFO mapreduce.Job:  map 93% reduce 0%
# 17/10/06 12:57:32 INFO mapreduce.Job:  map 100% reduce 0%
# 17/10/06 12:57:38 INFO mapreduce.Job:  map 100% reduce 43%
# 17/10/06 12:57:41 INFO mapreduce.Job:  map 100% reduce 51%
# 17/10/06 12:57:44 INFO mapreduce.Job:  map 100% reduce 58%
# 17/10/06 12:57:47 INFO mapreduce.Job:  map 100% reduce 66%
# 17/10/06 12:57:50 INFO mapreduce.Job:  map 100% reduce 70%
# 17/10/06 12:57:53 INFO mapreduce.Job:  map 100% reduce 75%
# 17/10/06 12:57:56 INFO mapreduce.Job:  map 100% reduce 79%
# 17/10/06 12:57:59 INFO mapreduce.Job:  map 100% reduce 84%
# 17/10/06 12:58:02 INFO mapreduce.Job:  map 100% reduce 89%
# 17/10/06 12:58:05 INFO mapreduce.Job:  map 100% reduce 93%
# 17/10/06 12:58:08 INFO mapreduce.Job:  map 100% reduce 98%
# 17/10/06 12:58:11 INFO mapreduce.Job:  map 100% reduce 100%
# 17/10/06 12:58:12 INFO mapreduce.Job: Job job_1505269880969_0066 completed successfully
# 17/10/06 12:58:12 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=1269290229
# 		FILE: Number of bytes written=2539560821
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=663945432
# 		HDFS: Number of bytes written=2045080
# 		HDFS: Number of read operations=18
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=5
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Rack-local map tasks=3
# 		Total time spent by all maps in occupied slots (ms)=347241
# 		Total time spent by all reduces in occupied slots (ms)=128535
# 		Total time spent by all map tasks (ms)=115747
# 		Total time spent by all reduce tasks (ms)=42845
# 		Total vcore-milliseconds taken by all map tasks=115747
# 		Total vcore-milliseconds taken by all reduce tasks=42845
# 		Total megabyte-milliseconds taken by all map tasks=1492210324
# 		Total megabyte-milliseconds taken by all reduce tasks=552357740
# 	Map-Reduce Framework
# 		Map input records=24404097
# 		Map output records=24404096
# 		Map output bytes=1220481613
# 		Map output materialized bytes=1269290253
# 		Input split bytes=480
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=39408
# 		Reduce shuffle bytes=1269290253
# 		Reduce input records=24404096
# 		Reduce output records=39408
# 		Spilled Records=48808192
# 		Shuffled Maps =5
# 		Failed Shuffles=0
# 		Merged Map outputs=5
# 		GC time elapsed (ms)=3744
# 		CPU time spent (ms)=242980
# 		Physical memory (bytes) snapshot=15988453376
# 		Virtual memory (bytes) snapshot=79746842624
# 		Total committed heap usage (bytes)=18200657920
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=663944952
# 	File Output Format Counters
# 		Bytes Written=2045080
# 17/10/06 12:58:12 INFO streaming.StreamJob: Output directory: intro-to-hadoop/output-movielens-02

# %%
# !hdfs dfs -ls intro-to-hadoop/output-movielens-02
# Out:
# Found 2 items
# -rw-r--r--   2 lngo hdfs          0 2017-10-06 12:58 intro-to-hadoop/output-movielens-02/_SUCCESS
# -rw-r--r--   2 lngo hdfs    2045080 2017-10-06 12:58 intro-to-hadoop/output-movielens-02/part-00000

# %%
# !hdfs dfs -cat intro-to-hadoop/output-movielens-02/part-00000 \
    2>/dev/null | head -n 20
# Out:
# "Great Performances" Cats (1998)	2.78199052133	Comedy|Drama
# #1 Cheerleader Camp (2010)	2.75	Drama|Horror|Mystery|Thriller
# #Horror (2015)	2.22222222222	Documentary
# #chicagoGirl: The Social Network Takes on a Dictator (2013)	3.66666666667	Comedy|Crime|Drama
# $ (Dollars) (1971)	2.75	Western
# $1,000 on the Black (1966)	3.0	Drama|Western
# $100,000 for Ringo (1965)	2.5	Comedy|Drama
# $5 a Day (2008)	2.97169811321	Drama
# $50K and a Call Girl: A Love Story (2014)	3.75	Animation
# $9.99 (2008)	3.13846153846	Documentary
# $ellebrity (Sellebrity) (2012)	2.25	Comedy|Western
# '49-'17 (1917)	2.5	Action|Drama|Thriller|War
# '71 (2014)	3.69689119171	Action|Adventure|Comedy|Documentary|Fantasy
# 'Hellboy': The Seeds of Creation (2004)	3.05909090909	Drama|Thriller
# 'Human' Factor, The (Human Factor, The) (1975)	2.25	Drama
# 'Master Harold'... and the Boys (1985)	3.5	Western
# 'Neath the Arizona Skies (1934)	2.29166666667	Action
# 'Pimpernel' Smith (1941)	3.0	Crime|Drama
# 'R Xmas (2001)	2.75	Drama|Musical
# 'Round Midnight (1986)	3.61594202899	Drama|Horror|Mystery|Thriller

# %% [markdown]
# ### Challenge:
#
# 1. Modify *avgRatingReducer02.py* so that only movies with averaged ratings higher than 3.75 are collected
# 2. Further enhance your modification so that not only movies with averaged ratings higher than 3.75 are collected but these movies also need to be rated at least 5000 times.

# %%
# %%writefile codes/avgRatingMapper04challenge.py
#!/usr/bin/env python

import sys
import csv

movieFile = "./movies.csv"
movieList = {}


with open(movieFile, mode = 'r') as infile:
    reader = csv.reader(infile)
    for row in reader:
        movieList[row[0]] = {}
        movieList[row[0]]["title"] = row[1]
        movieList[row[0]]["genre"] = row[2]

for oneMovie in sys.stdin:
    oneMovie = oneMovie.strip()
    ratingInfo = oneMovie.split(",")
    try:
        movieTitle = movieList[ratingInfo[1]]["title"]
        movieGenre = movieList[ratingInfo[1]]["genre"]
        rating = float(ratingInfo[2])
        if _________:
            print ("%s\t%s\t%s" % (movieTitle, rating, movieGenre))
    except ValueError:
        continue

# %%
# !yarn jar /usr/hdp/current/hadoop-mapreduce-client/hadoop-streaming.jar \
    -input /repository/movielens/ratings.csv \
    -output intro-to-hadoop/output-movielens-challenge \
    -file ____________ \
    -mapper ___________ \
    -file ./codes/avgRatingReducer01.py \
    -reducer avgRatingReducer01.py \
    -file ./codes/movielens/movies.csv
